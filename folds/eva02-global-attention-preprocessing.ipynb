# %%
import pandas as pd
import os

def get_image_path(image_id:int):
    return os.path.join('../tiles_768', str(image_id))

train = pd.read_csv(f"../data/train.csv")

train['tile_path'] = train['image_id'].apply(lambda x: get_image_path(x))
train.head()
# Out:
#    image_id label  image_width  image_height  is_tma         tile_path
# 0         4  HGSC        23785         20008   False    ../tiles_768/4
# 1        66  LGSC        48871         48195   False   ../tiles_768/66
# 2        91  HGSC         3388          3388    True   ../tiles_768/91
# 3       281  LGSC        42309         15545   False  ../tiles_768/281
# 4       286    EC        37204         30020   False  ../tiles_768/286

# %%
from PIL import Image
import torch
import torch.nn as nn
import timm
from timm.models.layers import DropPath
import copy

device = "cuda" if torch.cuda.is_available() else "cpu"
    model_name = "timm/eva02_base_patch14_448.mim_in22k_ft_in22k_in1k"

print(f"Using device {device} and model {model_name}")

model = timm.create_model(model_name, pretrained=True)

# Define the maximum drop path rate
# for folds 0 1 3 4
max_drop_path_rate = 0.3
dropout_rate = 0.1
"""
# for folds 2
max_drop_path_rate = 0.15
dropout_rate = 0.0
"""

drop_path_rates = [x.item() for x in torch.linspace(0, max_drop_path_rate, len(model.blocks))]

# Assign drop path rates
for i, block in enumerate(model.blocks):
    block.drop_path1 = DropPath(drop_prob=drop_path_rates[i])
    block.drop_path2 = DropPath(drop_prob=drop_path_rates[i])
    block.attn.attn_drop = nn.Dropout(p=dropout_rate, inplace=False)
    block.attn.proj_drop = nn.Dropout(p=dropout_rate, inplace=False)
    block.mlp.drop1 = nn.Dropout(p=dropout_rate, inplace=False)
    block.mlp.drop2 = nn.Dropout(p=dropout_rate, inplace=False)

model.head = nn.Linear(model.head.in_features, 5)

state_dict = torch.load('eva02_base_models/fold_1/epoch_0_step_16000.pth', map_location=device)
model.load_state_dict(state_dict, strict=False)

# model.head == nn.Linear(768, 5)
model.head = nn.Identity()

model = model.to(device)
# Out:
# Using device cuda and model timm/eva02_base_patch14_448.mim_in22k_ft_in22k_in1k
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
import os
from PIL import Image
from torch.utils.data import Dataset
import random

integer_to_label = {
    0: 'HGSC',
    1: 'CC',
    2: 'EC',
    3: 'LGSC',
    4: 'MC',
}

label_to_integer = {
    'HGSC': 0,
    'CC': 1,
    'EC': 2,
    'LGSC': 3,
    'MC': 4,
}

class ImageDataset(Dataset):
    def __init__(self, folder_path, transform=None):
        self.folder_path = folder_path
        self.transform = transform
        self.image_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.lower().endswith('.png')]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        image_path = random.choice(self.image_files)
        image = Image.open(image_path)

        if self.transform:
            image = self.transform(image)
        
        return image

# %%
import torchvision.transforms as transforms

train_transform = transforms.Compose([
    transforms.Resize(448),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711]),
])

# %%
from torch.utils.data import DataLoader
import torch
import os

BATCH_SIZE = 256
save_folder = '../image_tensors'

# Make sure the save directory exists
os.makedirs(save_folder, exist_ok=True)

model.eval()
with torch.no_grad():
    for index, row in train.iterrows():
        image_id = row['image_id']
        save_path = os.path.join(save_folder, f"{image_id}.pt")

        # Check if the tensor for this image_id already exists
        if os.path.exists(save_path):
            print(f"Tensor for image_id {image_id} already exists at {save_path}. Skipping computation.")
            continue

        folder_path = row['tile_path']
        label = row['label']
        dataset = ImageDataset(folder_path=folder_path, transform=train_transform)
        dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, num_workers=8)
        all_tensors = []
        for images in dataloader:
            images = images.to(device)
            output = model(images)
            all_tensors.append(output)
        concatenated_tensor = torch.cat(all_tensors, dim=0)

        # Save the concatenated tensor
        torch.save(concatenated_tensor, save_path)
        print(f"Saved tensor for image_id {image_id} at {save_path} with shape {concatenated_tensor.shape}")
# Out:
# Tensor for image_id 4 already exists at ../image_tensors/4.pt. Skipping computation.
# Tensor for image_id 66 already exists at ../image_tensors/66.pt. Skipping computation.
# Tensor for image_id 91 already exists at ../image_tensors/91.pt. Skipping computation.
# Tensor for image_id 281 already exists at ../image_tensors/281.pt. Skipping computation.
# Tensor for image_id 286 already exists at ../image_tensors/286.pt. Skipping computation.
# Tensor for image_id 431 already exists at ../image_tensors/431.pt. Skipping computation.
# Tensor for image_id 706 already exists at ../image_tensors/706.pt. Skipping computation.
# Tensor for image_id 970 already exists at ../image_tensors/970.pt. Skipping computation.
# Tensor for image_id 1020 already exists at ../image_tensors/1020.pt. Skipping computation.
# Saved tensor for image_id 1080 at ../image_tensors/1080.pt with shape torch.Size([620, 768])
# Saved tensor for image_id 1101 at ../image_tensors/1101.pt with shape torch.Size([454, 768])
# Saved tensor for image_id 1289 at ../image_tensors/1289.pt with shape torch.Size([850, 768])
# Saved tensor for image_id 1295 at ../image_tensors/1295.pt with shape torch.Size([558, 768])
# Saved tensor for image_id 1660 at ../image_tensors/1660.pt with shape torch.Size([1167, 768])
# Saved tensor for image_id 1666 at ../image_tensors/1666.pt with shape torch.Size([497, 768])
# Saved tensor for image_id 1774 at ../image_tensors/1774.pt with shape torch.Size([1448, 768])
# Saved tensor for image_id 1925 at ../image_tensors/1925.pt with shape torch.Size([1731, 768])
# Saved tensor for image_id 1943 at ../image_tensors/1943.pt with shape torch.Size([1750, 768])
# Saved tensor for image_id 1952 at ../image_tensors/1952.pt with shape torch.Size([1066, 768])
# Saved tensor for image_id 2097 at ../image_tensors/2097.pt with shape torch.Size([764, 768])
# Saved tensor for image_id 2227 at ../image_tensors/2227.pt with shape torch.Size([2252, 768])
# Saved tensor for image_id 2391 at ../image_tensors/2391.pt with shape torch.Size([1021, 768])
# Saved tensor for image_id 2666 at ../image_tensors/2666.pt with shape torch.Size([1920, 768])
# Saved tensor for image_id 2706 at ../image_tensors/2706.pt with shape torch.Size([1021, 768])
# Saved tensor for image_id 2906 at ../image_tensors/2906.pt with shape torch.Size([1583, 768])
# Saved tensor for image_id 3055 at ../image_tensors/3055.pt with shape torch.Size([2329, 768])
# Saved tensor for image_id 3084 at ../image_tensors/3084.pt with shape torch.Size([1902, 768])
# Saved tensor for image_id 3092 at ../image_tensors/3092.pt with shape torch.Size([514, 768])
# Saved tensor for image_id 3098 at ../image_tensors/3098.pt with shape torch.Size([1574, 768])
# Saved tensor for image_id 3191 at ../image_tensors/3191.pt with shape torch.Size([228, 768])
# Saved tensor for image_id 3222 at ../image_tensors/3222.pt with shape torch.Size([657, 768])
# Saved tensor for image_id 3264 at ../image_tensors/3264.pt with shape torch.Size([1342, 768])
# Saved tensor for image_id 3511 at ../image_tensors/3511.pt with shape torch.Size([510, 768])
# Saved tensor for image_id 3672 at ../image_tensors/3672.pt with shape torch.Size([917, 768])
# Saved tensor for image_id 3881 at ../image_tensors/3881.pt with shape torch.Size([438, 768])
# Saved tensor for image_id 3997 at ../image_tensors/3997.pt with shape torch.Size([1368, 768])
# Saved tensor for image_id 4134 at ../image_tensors/4134.pt with shape torch.Size([15, 768])
# Saved tensor for image_id 4211 at ../image_tensors/4211.pt with shape torch.Size([1029, 768])
# Saved tensor for image_id 4608 at ../image_tensors/4608.pt with shape torch.Size([1186, 768])
# Saved tensor for image_id 4797 at ../image_tensors/4797.pt with shape torch.Size([2051, 768])
# Saved tensor for image_id 4827 at ../image_tensors/4827.pt with shape torch.Size([952, 768])
# Saved tensor for image_id 4877 at ../image_tensors/4877.pt with shape torch.Size([2655, 768])
# Saved tensor for image_id 4963 at ../image_tensors/4963.pt with shape torch.Size([2072, 768])
# Saved tensor for image_id 5015 at ../image_tensors/5015.pt with shape torch.Size([2236, 768])
# Saved tensor for image_id 5114 at ../image_tensors/5114.pt with shape torch.Size([923, 768])
# Saved tensor for image_id 5251 at ../image_tensors/5251.pt with shape torch.Size([1664, 768])
# Saved tensor for image_id 5264 at ../image_tensors/5264.pt with shape torch.Size([768, 768])
# Saved tensor for image_id 5265 at ../image_tensors/5265.pt with shape torch.Size([3075, 768])
# Saved tensor for image_id 5307 at ../image_tensors/5307.pt with shape torch.Size([1174, 768])
# Saved tensor for image_id 5456 at ../image_tensors/5456.pt with shape torch.Size([1977, 768])
# Saved tensor for image_id 5851 at ../image_tensors/5851.pt with shape torch.Size([1106, 768])
# Saved tensor for image_id 5852 at ../image_tensors/5852.pt with shape torch.Size([1135, 768])
# Saved tensor for image_id 5970 at ../image_tensors/5970.pt with shape torch.Size([634, 768])
# Saved tensor for image_id 5992 at ../image_tensors/5992.pt with shape torch.Size([1144, 768])
# Saved tensor for image_id 6140 at ../image_tensors/6140.pt with shape torch.Size([1401, 768])
# Saved tensor for image_id 6175 at ../image_tensors/6175.pt with shape torch.Size([1491, 768])
# Saved tensor for image_id 6281 at ../image_tensors/6281.pt with shape torch.Size([3275, 768])
# Saved tensor for image_id 6359 at ../image_tensors/6359.pt with shape torch.Size([1910, 768])
# Saved tensor for image_id 6363 at ../image_tensors/6363.pt with shape torch.Size([1373, 768])
# Saved tensor for image_id 6449 at ../image_tensors/6449.pt with shape torch.Size([2809, 768])
# Saved tensor for image_id 6558 at ../image_tensors/6558.pt with shape torch.Size([1980, 768])
# Saved tensor for image_id 6582 at ../image_tensors/6582.pt with shape torch.Size([863, 768])
# Saved tensor for image_id 6793 at ../image_tensors/6793.pt with shape torch.Size([2149, 768])
# Saved tensor for image_id 6843 at ../image_tensors/6843.pt with shape torch.Size([3218, 768])
# Saved tensor for image_id 6898 at ../image_tensors/6898.pt with shape torch.Size([1544, 768])
# Saved tensor for image_id 6951 at ../image_tensors/6951.pt with shape torch.Size([1858, 768])
# Saved tensor for image_id 7204 at ../image_tensors/7204.pt with shape torch.Size([556, 768])
# Saved tensor for image_id 7329 at ../image_tensors/7329.pt with shape torch.Size([965, 768])
# Saved tensor for image_id 7482 at ../image_tensors/7482.pt with shape torch.Size([1902, 768])
# Saved tensor for image_id 7490 at ../image_tensors/7490.pt with shape torch.Size([2546, 768])
# Saved tensor for image_id 7955 at ../image_tensors/7955.pt with shape torch.Size([582, 768])
# Saved tensor for image_id 8130 at ../image_tensors/8130.pt with shape torch.Size([1356, 768])
# Saved tensor for image_id 8213 at ../image_tensors/8213.pt with shape torch.Size([692, 768])
# Saved tensor for image_id 8240 at ../image_tensors/8240.pt with shape torch.Size([1565, 768])
# Saved tensor for image_id 8279 at ../image_tensors/8279.pt with shape torch.Size([2447, 768])
# Saved tensor for image_id 8280 at ../image_tensors/8280.pt with shape torch.Size([16, 768])
# Saved tensor for image_id 8531 at ../image_tensors/8531.pt with shape torch.Size([1726, 768])
# Saved tensor for image_id 8713 at ../image_tensors/8713.pt with shape torch.Size([3364, 768])
# Saved tensor for image_id 8805 at ../image_tensors/8805.pt with shape torch.Size([476, 768])
# Saved tensor for image_id 8985 at ../image_tensors/8985.pt with shape torch.Size([819, 768])
# Saved tensor for image_id 9154 at ../image_tensors/9154.pt with shape torch.Size([268, 768])
# Saved tensor for image_id 9183 at ../image_tensors/9183.pt with shape torch.Size([1488, 768])
# Saved tensor for image_id 9200 at ../image_tensors/9200.pt with shape torch.Size([15, 768])
# Saved tensor for image_id 9254 at ../image_tensors/9254.pt with shape torch.Size([2547, 768])
# Saved tensor for image_id 9341 at ../image_tensors/9341.pt with shape torch.Size([1689, 768])
# Saved tensor for image_id 9509 at ../image_tensors/9509.pt with shape torch.Size([588, 768])
# Saved tensor for image_id 9658 at ../image_tensors/9658.pt with shape torch.Size([2325, 768])
# Saved tensor for image_id 9697 at ../image_tensors/9697.pt with shape torch.Size([800, 768])
# Saved tensor for image_id 10077 at ../image_tensors/10077.pt with shape torch.Size([2023, 768])
# Saved tensor for image_id 10143 at ../image_tensors/10143.pt with shape torch.Size([1899, 768])
# Saved tensor for image_id 10246 at ../image_tensors/10246.pt with shape torch.Size([1754, 768])
# Saved tensor for image_id 10252 at ../image_tensors/10252.pt with shape torch.Size([979, 768])
# Saved tensor for image_id 10469 at ../image_tensors/10469.pt with shape torch.Size([1153, 768])
# Saved tensor for image_id 10548 at ../image_tensors/10548.pt with shape torch.Size([1128, 768])
# Saved tensor for image_id 10642 at ../image_tensors/10642.pt with shape torch.Size([1889, 768])
# Saved tensor for image_id 10800 at ../image_tensors/10800.pt with shape torch.Size([1328, 768])
# Saved tensor for image_id 10896 at ../image_tensors/10896.pt with shape torch.Size([2196, 768])
# Saved tensor for image_id 11263 at ../image_tensors/11263.pt with shape torch.Size([916, 768])
# Saved tensor for image_id 11417 at ../image_tensors/11417.pt with shape torch.Size([1078, 768])
# Saved tensor for image_id 11431 at ../image_tensors/11431.pt with shape torch.Size([928, 768])
# Saved tensor for image_id 11557 at ../image_tensors/11557.pt with shape torch.Size([464, 768])
# Saved tensor for image_id 11559 at ../image_tensors/11559.pt with shape torch.Size([503, 768])
# Saved tensor for image_id 12159 at ../image_tensors/12159.pt with shape torch.Size([596, 768])
# Saved tensor for image_id 12222 at ../image_tensors/12222.pt with shape torch.Size([1128, 768])
# Saved tensor for image_id 12244 at ../image_tensors/12244.pt with shape torch.Size([462, 768])
# Saved tensor for image_id 12442 at ../image_tensors/12442.pt with shape torch.Size([2575, 768])
# Saved tensor for image_id 12522 at ../image_tensors/12522.pt with shape torch.Size([1984, 768])
# Saved tensor for image_id 12902 at ../image_tensors/12902.pt with shape torch.Size([2213, 768])
# Saved tensor for image_id 13364 at ../image_tensors/13364.pt with shape torch.Size([253, 768])
# Saved tensor for image_id 13387 at ../image_tensors/13387.pt with shape torch.Size([533, 768])
# Saved tensor for image_id 13526 at ../image_tensors/13526.pt with shape torch.Size([2157, 768])
# Saved tensor for image_id 13568 at ../image_tensors/13568.pt with shape torch.Size([16, 768])
# Saved tensor for image_id 13987 at ../image_tensors/13987.pt with shape torch.Size([1882, 768])
# Saved tensor for image_id 14039 at ../image_tensors/14039.pt with shape torch.Size([254, 768])
# Saved tensor for image_id 14051 at ../image_tensors/14051.pt with shape torch.Size([713, 768])
# Saved tensor for image_id 14127 at ../image_tensors/14127.pt with shape torch.Size([1108, 768])
# Saved tensor for image_id 14312 at ../image_tensors/14312.pt with shape torch.Size([1436, 768])
# Saved tensor for image_id 14401 at ../image_tensors/14401.pt with shape torch.Size([2410, 768])
# Saved tensor for image_id 14424 at ../image_tensors/14424.pt with shape torch.Size([3399, 768])
# Saved tensor for image_id 14532 at ../image_tensors/14532.pt with shape torch.Size([1494, 768])
# Saved tensor for image_id 14542 at ../image_tensors/14542.pt with shape torch.Size([1185, 768])
# Saved tensor for image_id 14617 at ../image_tensors/14617.pt with shape torch.Size([543, 768])
# Saved tensor for image_id 15139 at ../image_tensors/15139.pt with shape torch.Size([2704, 768])
# Saved tensor for image_id 15188 at ../image_tensors/15188.pt with shape torch.Size([3049, 768])
# Saved tensor for image_id 15209 at ../image_tensors/15209.pt with shape torch.Size([1892, 768])
# Saved tensor for image_id 15221 at ../image_tensors/15221.pt with shape torch.Size([494, 768])
# Saved tensor for image_id 15231 at ../image_tensors/15231.pt with shape torch.Size([3101, 768])
# Saved tensor for image_id 15293 at ../image_tensors/15293.pt with shape torch.Size([678, 768])
# Saved tensor for image_id 15470 at ../image_tensors/15470.pt with shape torch.Size([503, 768])
# Saved tensor for image_id 15486 at ../image_tensors/15486.pt with shape torch.Size([1203, 768])
# Saved tensor for image_id 15583 at ../image_tensors/15583.pt with shape torch.Size([634, 768])
# Saved tensor for image_id 15671 at ../image_tensors/15671.pt with shape torch.Size([975, 768])
# Saved tensor for image_id 15742 at ../image_tensors/15742.pt with shape torch.Size([2891, 768])
# Saved tensor for image_id 15871 at ../image_tensors/15871.pt with shape torch.Size([659, 768])
# Saved tensor for image_id 15912 at ../image_tensors/15912.pt with shape torch.Size([1001, 768])
# Saved tensor for image_id 16042 at ../image_tensors/16042.pt with shape torch.Size([1161, 768])
# Saved tensor for image_id 16064 at ../image_tensors/16064.pt with shape torch.Size([1760, 768])
# Saved tensor for image_id 16209 at ../image_tensors/16209.pt with shape torch.Size([1396, 768])
# Saved tensor for image_id 16325 at ../image_tensors/16325.pt with shape torch.Size([1694, 768])
# Saved tensor for image_id 16494 at ../image_tensors/16494.pt with shape torch.Size([347, 768])
# Saved tensor for image_id 16876 at ../image_tensors/16876.pt with shape torch.Size([494, 768])
# Saved tensor for image_id 16986 at ../image_tensors/16986.pt with shape torch.Size([895, 768])
# Saved tensor for image_id 17067 at ../image_tensors/17067.pt with shape torch.Size([1579, 768])
# Saved tensor for image_id 17174 at ../image_tensors/17174.pt with shape torch.Size([833, 768])
# Saved tensor for image_id 17291 at ../image_tensors/17291.pt with shape torch.Size([2245, 768])
# Saved tensor for image_id 17365 at ../image_tensors/17365.pt with shape torch.Size([1258, 768])
# Saved tensor for image_id 17416 at ../image_tensors/17416.pt with shape torch.Size([2235, 768])
# Saved tensor for image_id 17487 at ../image_tensors/17487.pt with shape torch.Size([682, 768])
# Saved tensor for image_id 17637 at ../image_tensors/17637.pt with shape torch.Size([14, 768])
# Saved tensor for image_id 17738 at ../image_tensors/17738.pt with shape torch.Size([1157, 768])
# Saved tensor for image_id 17854 at ../image_tensors/17854.pt with shape torch.Size([1235, 768])
# Saved tensor for image_id 18014 at ../image_tensors/18014.pt with shape torch.Size([766, 768])
# Saved tensor for image_id 18138 at ../image_tensors/18138.pt with shape torch.Size([563, 768])
# Saved tensor for image_id 18196 at ../image_tensors/18196.pt with shape torch.Size([1056, 768])
# Saved tensor for image_id 18547 at ../image_tensors/18547.pt with shape torch.Size([1442, 768])
# Saved tensor for image_id 18568 at ../image_tensors/18568.pt with shape torch.Size([2443, 768])
# Saved tensor for image_id 18607 at ../image_tensors/18607.pt with shape torch.Size([1786, 768])
# Saved tensor for image_id 18810 at ../image_tensors/18810.pt with shape torch.Size([2152, 768])
# Saved tensor for image_id 18813 at ../image_tensors/18813.pt with shape torch.Size([2060, 768])
# Saved tensor for image_id 18896 at ../image_tensors/18896.pt with shape torch.Size([661, 768])
# Saved tensor for image_id 18914 at ../image_tensors/18914.pt with shape torch.Size([987, 768])
# Saved tensor for image_id 18981 at ../image_tensors/18981.pt with shape torch.Size([1368, 768])
# Saved tensor for image_id 19030 at ../image_tensors/19030.pt with shape torch.Size([393, 768])
# Saved tensor for image_id 19157 at ../image_tensors/19157.pt with shape torch.Size([1477, 768])
# Saved tensor for image_id 19255 at ../image_tensors/19255.pt with shape torch.Size([2908, 768])
# Saved tensor for image_id 19512 at ../image_tensors/19512.pt with shape torch.Size([2435, 768])
# Saved tensor for image_id 19569 at ../image_tensors/19569.pt with shape torch.Size([1243, 768])
# Saved tensor for image_id 20205 at ../image_tensors/20205.pt with shape torch.Size([722, 768])
# Saved tensor for image_id 20312 at ../image_tensors/20312.pt with shape torch.Size([2264, 768])
# Saved tensor for image_id 20316 at ../image_tensors/20316.pt with shape torch.Size([1685, 768])
# Saved tensor for image_id 20329 at ../image_tensors/20329.pt with shape torch.Size([3304, 768])
# Saved tensor for image_id 20463 at ../image_tensors/20463.pt with shape torch.Size([2427, 768])
# Saved tensor for image_id 20670 at ../image_tensors/20670.pt with shape torch.Size([732, 768])
# Saved tensor for image_id 20858 at ../image_tensors/20858.pt with shape torch.Size([482, 768])
# Saved tensor for image_id 20882 at ../image_tensors/20882.pt with shape torch.Size([920, 768])
# Saved tensor for image_id 21020 at ../image_tensors/21020.pt with shape torch.Size([14, 768])
# Saved tensor for image_id 21232 at ../image_tensors/21232.pt with shape torch.Size([419, 768])
# Saved tensor for image_id 21260 at ../image_tensors/21260.pt with shape torch.Size([595, 768])
# Saved tensor for image_id 21303 at ../image_tensors/21303.pt with shape torch.Size([1953, 768])
# Saved tensor for image_id 21373 at ../image_tensors/21373.pt with shape torch.Size([1175, 768])
# Saved tensor for image_id 21432 at ../image_tensors/21432.pt with shape torch.Size([1799, 768])
# Saved tensor for image_id 21445 at ../image_tensors/21445.pt with shape torch.Size([919, 768])
# Saved tensor for image_id 21910 at ../image_tensors/21910.pt with shape torch.Size([1661, 768])
# Saved tensor for image_id 21929 at ../image_tensors/21929.pt with shape torch.Size([1219, 768])
# Saved tensor for image_id 22155 at ../image_tensors/22155.pt with shape torch.Size([1759, 768])
# Saved tensor for image_id 22221 at ../image_tensors/22221.pt with shape torch.Size([1447, 768])
# Saved tensor for image_id 22290 at ../image_tensors/22290.pt with shape torch.Size([1034, 768])
# Saved tensor for image_id 22425 at ../image_tensors/22425.pt with shape torch.Size([1712, 768])
# Saved tensor for image_id 22489 at ../image_tensors/22489.pt with shape torch.Size([569, 768])
# Saved tensor for image_id 22654 at ../image_tensors/22654.pt with shape torch.Size([1833, 768])
# Saved tensor for image_id 22740 at ../image_tensors/22740.pt with shape torch.Size([772, 768])
# Saved tensor for image_id 22924 at ../image_tensors/22924.pt with shape torch.Size([710, 768])
# Saved tensor for image_id 23523 at ../image_tensors/23523.pt with shape torch.Size([2516, 768])
# Saved tensor for image_id 23629 at ../image_tensors/23629.pt with shape torch.Size([1223, 768])
# Saved tensor for image_id 23796 at ../image_tensors/23796.pt with shape torch.Size([1174, 768])
# Saved tensor for image_id 24023 at ../image_tensors/24023.pt with shape torch.Size([1425, 768])
# Saved tensor for image_id 24507 at ../image_tensors/24507.pt with shape torch.Size([804, 768])
# Saved tensor for image_id 24617 at ../image_tensors/24617.pt with shape torch.Size([1073, 768])
# Saved tensor for image_id 24759 at ../image_tensors/24759.pt with shape torch.Size([1566, 768])
# Saved tensor for image_id 24991 at ../image_tensors/24991.pt with shape torch.Size([796, 768])
# Saved tensor for image_id 25256 at ../image_tensors/25256.pt with shape torch.Size([759, 768])
# Saved tensor for image_id 25331 at ../image_tensors/25331.pt with shape torch.Size([2118, 768])
# Saved tensor for image_id 25561 at ../image_tensors/25561.pt with shape torch.Size([440, 768])
# Saved tensor for image_id 25604 at ../image_tensors/25604.pt with shape torch.Size([641, 768])
# Saved tensor for image_id 25792 at ../image_tensors/25792.pt with shape torch.Size([369, 768])
# Saved tensor for image_id 25923 at ../image_tensors/25923.pt with shape torch.Size([892, 768])
# Saved tensor for image_id 25928 at ../image_tensors/25928.pt with shape torch.Size([1293, 768])
# Saved tensor for image_id 26025 at ../image_tensors/26025.pt with shape torch.Size([1489, 768])
# Saved tensor for image_id 26124 at ../image_tensors/26124.pt with shape torch.Size([606, 768])
# Saved tensor for image_id 26190 at ../image_tensors/26190.pt with shape torch.Size([1109, 768])
# Saved tensor for image_id 26219 at ../image_tensors/26219.pt with shape torch.Size([2734, 768])
# Saved tensor for image_id 26533 at ../image_tensors/26533.pt with shape torch.Size([572, 768])
# Saved tensor for image_id 26603 at ../image_tensors/26603.pt with shape torch.Size([2692, 768])
# Saved tensor for image_id 26644 at ../image_tensors/26644.pt with shape torch.Size([702, 768])
# Saved tensor for image_id 26862 at ../image_tensors/26862.pt with shape torch.Size([2263, 768])
# Saved tensor for image_id 26939 at ../image_tensors/26939.pt with shape torch.Size([1123, 768])
# Saved tensor for image_id 26950 at ../image_tensors/26950.pt with shape torch.Size([1774, 768])
# Saved tensor for image_id 27245 at ../image_tensors/27245.pt with shape torch.Size([1653, 768])
# Saved tensor for image_id 27249 at ../image_tensors/27249.pt with shape torch.Size([555, 768])
# Saved tensor for image_id 27315 at ../image_tensors/27315.pt with shape torch.Size([1081, 768])
# Saved tensor for image_id 27739 at ../image_tensors/27739.pt with shape torch.Size([1451, 768])
# Saved tensor for image_id 27747 at ../image_tensors/27747.pt with shape torch.Size([1503, 768])
# Saved tensor for image_id 27851 at ../image_tensors/27851.pt with shape torch.Size([1294, 768])
# Saved tensor for image_id 27950 at ../image_tensors/27950.pt with shape torch.Size([596, 768])
# Saved tensor for image_id 28028 at ../image_tensors/28028.pt with shape torch.Size([2676, 768])
# Saved tensor for image_id 28066 at ../image_tensors/28066.pt with shape torch.Size([1493, 768])
# Saved tensor for image_id 28121 at ../image_tensors/28121.pt with shape torch.Size([1616, 768])
# Saved tensor for image_id 28393 at ../image_tensors/28393.pt with shape torch.Size([765, 768])
# Saved tensor for image_id 28519 at ../image_tensors/28519.pt with shape torch.Size([404, 768])
# Saved tensor for image_id 28562 at ../image_tensors/28562.pt with shape torch.Size([1470, 768])
# Saved tensor for image_id 28603 at ../image_tensors/28603.pt with shape torch.Size([1467, 768])
# Saved tensor for image_id 28736 at ../image_tensors/28736.pt with shape torch.Size([329, 768])
# Saved tensor for image_id 28821 at ../image_tensors/28821.pt with shape torch.Size([947, 768])
# Saved tensor for image_id 28922 at ../image_tensors/28922.pt with shape torch.Size([1145, 768])
# Saved tensor for image_id 29084 at ../image_tensors/29084.pt with shape torch.Size([15, 768])
# Saved tensor for image_id 29147 at ../image_tensors/29147.pt with shape torch.Size([789, 768])
# Saved tensor for image_id 29200 at ../image_tensors/29200.pt with shape torch.Size([2692, 768])
# Saved tensor for image_id 29240 at ../image_tensors/29240.pt with shape torch.Size([1098, 768])
# Saved tensor for image_id 29331 at ../image_tensors/29331.pt with shape torch.Size([1839, 768])
# Saved tensor for image_id 29615 at ../image_tensors/29615.pt with shape torch.Size([1395, 768])
# Saved tensor for image_id 29888 at ../image_tensors/29888.pt with shape torch.Size([341, 768])
# Saved tensor for image_id 29904 at ../image_tensors/29904.pt with shape torch.Size([885, 768])
# Saved tensor for image_id 29915 at ../image_tensors/29915.pt with shape torch.Size([1765, 768])
# Saved tensor for image_id 30203 at ../image_tensors/30203.pt with shape torch.Size([2261, 768])
# Saved tensor for image_id 30272 at ../image_tensors/30272.pt with shape torch.Size([1128, 768])
# Saved tensor for image_id 30369 at ../image_tensors/30369.pt with shape torch.Size([2554, 768])
# Saved tensor for image_id 30508 at ../image_tensors/30508.pt with shape torch.Size([1168, 768])
# Saved tensor for image_id 30515 at ../image_tensors/30515.pt with shape torch.Size([1477, 768])
# Saved tensor for image_id 30539 at ../image_tensors/30539.pt with shape torch.Size([640, 768])
# Saved tensor for image_id 30712 at ../image_tensors/30712.pt with shape torch.Size([1567, 768])
# Saved tensor for image_id 30738 at ../image_tensors/30738.pt with shape torch.Size([789, 768])
# Saved tensor for image_id 30792 at ../image_tensors/30792.pt with shape torch.Size([1351, 768])
# Saved tensor for image_id 30794 at ../image_tensors/30794.pt with shape torch.Size([2594, 768])
# Saved tensor for image_id 30868 at ../image_tensors/30868.pt with shape torch.Size([993, 768])
# Saved tensor for image_id 30986 at ../image_tensors/30986.pt with shape torch.Size([2919, 768])
# Saved tensor for image_id 31033 at ../image_tensors/31033.pt with shape torch.Size([1182, 768])
# Saved tensor for image_id 31297 at ../image_tensors/31297.pt with shape torch.Size([3417, 768])
# Saved tensor for image_id 31300 at ../image_tensors/31300.pt with shape torch.Size([438, 768])
# Saved tensor for image_id 31333 at ../image_tensors/31333.pt with shape torch.Size([1046, 768])
# Saved tensor for image_id 31383 at ../image_tensors/31383.pt with shape torch.Size([2467, 768])
# Saved tensor for image_id 31473 at ../image_tensors/31473.pt with shape torch.Size([344, 768])
# Saved tensor for image_id 31594 at ../image_tensors/31594.pt with shape torch.Size([14, 768])
# Saved tensor for image_id 31793 at ../image_tensors/31793.pt with shape torch.Size([298, 768])
# Saved tensor for image_id 32032 at ../image_tensors/32032.pt with shape torch.Size([1516, 768])
# Saved tensor for image_id 32035 at ../image_tensors/32035.pt with shape torch.Size([734, 768])
# Saved tensor for image_id 32042 at ../image_tensors/32042.pt with shape torch.Size([992, 768])
# Saved tensor for image_id 32112 at ../image_tensors/32112.pt with shape torch.Size([835, 768])
# Saved tensor for image_id 32192 at ../image_tensors/32192.pt with shape torch.Size([224, 768])
# Saved tensor for image_id 32432 at ../image_tensors/32432.pt with shape torch.Size([698, 768])
# Saved tensor for image_id 32596 at ../image_tensors/32596.pt with shape torch.Size([1083, 768])
# Saved tensor for image_id 32636 at ../image_tensors/32636.pt with shape torch.Size([2321, 768])
# Saved tensor for image_id 33708 at ../image_tensors/33708.pt with shape torch.Size([1681, 768])
# Saved tensor for image_id 33839 at ../image_tensors/33839.pt with shape torch.Size([676, 768])
# Saved tensor for image_id 33976 at ../image_tensors/33976.pt with shape torch.Size([1079, 768])
# Saved tensor for image_id 33984 at ../image_tensors/33984.pt with shape torch.Size([1316, 768])
# Saved tensor for image_id 34247 at ../image_tensors/34247.pt with shape torch.Size([1092, 768])
# Saved tensor for image_id 34277 at ../image_tensors/34277.pt with shape torch.Size([1330, 768])
# Saved tensor for image_id 34508 at ../image_tensors/34508.pt with shape torch.Size([797, 768])
# Saved tensor for image_id 34649 at ../image_tensors/34649.pt with shape torch.Size([1338, 768])
# Saved tensor for image_id 34688 at ../image_tensors/34688.pt with shape torch.Size([535, 768])
# Saved tensor for image_id 34690 at ../image_tensors/34690.pt with shape torch.Size([576, 768])
# Saved tensor for image_id 34720 at ../image_tensors/34720.pt with shape torch.Size([676, 768])
# Saved tensor for image_id 34822 at ../image_tensors/34822.pt with shape torch.Size([1056, 768])
# Saved tensor for image_id 34845 at ../image_tensors/34845.pt with shape torch.Size([553, 768])
# Saved tensor for image_id 35197 at ../image_tensors/35197.pt with shape torch.Size([2699, 768])
# Saved tensor for image_id 35239 at ../image_tensors/35239.pt with shape torch.Size([2568, 768])
# Saved tensor for image_id 35565 at ../image_tensors/35565.pt with shape torch.Size([16, 768])
# Saved tensor for image_id 35592 at ../image_tensors/35592.pt with shape torch.Size([561, 768])
# Saved tensor for image_id 35652 at ../image_tensors/35652.pt with shape torch.Size([2522, 768])
# Saved tensor for image_id 35754 at ../image_tensors/35754.pt with shape torch.Size([1216, 768])
# Saved tensor for image_id 35792 at ../image_tensors/35792.pt with shape torch.Size([2722, 768])
# Saved tensor for image_id 35909 at ../image_tensors/35909.pt with shape torch.Size([1530, 768])
# Saved tensor for image_id 35953 at ../image_tensors/35953.pt with shape torch.Size([1711, 768])
# Saved tensor for image_id 35998 at ../image_tensors/35998.pt with shape torch.Size([934, 768])
# Saved tensor for image_id 36008 at ../image_tensors/36008.pt with shape torch.Size([894, 768])
# Saved tensor for image_id 36063 at ../image_tensors/36063.pt with shape torch.Size([1320, 768])
# Saved tensor for image_id 36204 at ../image_tensors/36204.pt with shape torch.Size([2189, 768])
# Saved tensor for image_id 36302 at ../image_tensors/36302.pt with shape torch.Size([19, 768])
# Saved tensor for image_id 36499 at ../image_tensors/36499.pt with shape torch.Size([832, 768])
# Saved tensor for image_id 36513 at ../image_tensors/36513.pt with shape torch.Size([2782, 768])
# Saved tensor for image_id 36583 at ../image_tensors/36583.pt with shape torch.Size([16, 768])
# Saved tensor for image_id 36639 at ../image_tensors/36639.pt with shape torch.Size([629, 768])
# Saved tensor for image_id 36678 at ../image_tensors/36678.pt with shape torch.Size([3965, 768])
# Saved tensor for image_id 36783 at ../image_tensors/36783.pt with shape torch.Size([16, 768])
# Saved tensor for image_id 37190 at ../image_tensors/37190.pt with shape torch.Size([2994, 768])
# Saved tensor for image_id 37307 at ../image_tensors/37307.pt with shape torch.Size([2179, 768])
# Saved tensor for image_id 37367 at ../image_tensors/37367.pt with shape torch.Size([1178, 768])
# Saved tensor for image_id 37385 at ../image_tensors/37385.pt with shape torch.Size([15, 768])
# Saved tensor for image_id 37655 at ../image_tensors/37655.pt with shape torch.Size([2218, 768])
# Saved tensor for image_id 38018 at ../image_tensors/38018.pt with shape torch.Size([774, 768])
# Saved tensor for image_id 38019 at ../image_tensors/38019.pt with shape torch.Size([2074, 768])
# Saved tensor for image_id 38041 at ../image_tensors/38041.pt with shape torch.Size([904, 768])
# Saved tensor for image_id 38048 at ../image_tensors/38048.pt with shape torch.Size([1899, 768])
# Saved tensor for image_id 38097 at ../image_tensors/38097.pt with shape torch.Size([1535, 768])
# Saved tensor for image_id 38118 at ../image_tensors/38118.pt with shape torch.Size([1569, 768])
# Saved tensor for image_id 38349 at ../image_tensors/38349.pt with shape torch.Size([1619, 768])
# Saved tensor for image_id 38366 at ../image_tensors/38366.pt with shape torch.Size([818, 768])
# Saved tensor for image_id 38479 at ../image_tensors/38479.pt with shape torch.Size([1669, 768])
# Saved tensor for image_id 38535 at ../image_tensors/38535.pt with shape torch.Size([1269, 768])
# Saved tensor for image_id 38585 at ../image_tensors/38585.pt with shape torch.Size([1199, 768])
# Saved tensor for image_id 38647 at ../image_tensors/38647.pt with shape torch.Size([1098, 768])
# Saved tensor for image_id 38669 at ../image_tensors/38669.pt with shape torch.Size([963, 768])
# Saved tensor for image_id 38687 at ../image_tensors/38687.pt with shape torch.Size([1222, 768])
# Saved tensor for image_id 38849 at ../image_tensors/38849.pt with shape torch.Size([1542, 768])
# Saved tensor for image_id 38901 at ../image_tensors/38901.pt with shape torch.Size([2056, 768])
# Saved tensor for image_id 38959 at ../image_tensors/38959.pt with shape torch.Size([434, 768])
# Saved tensor for image_id 39144 at ../image_tensors/39144.pt with shape torch.Size([659, 768])
# Saved tensor for image_id 39146 at ../image_tensors/39146.pt with shape torch.Size([768, 768])
# Saved tensor for image_id 39172 at ../image_tensors/39172.pt with shape torch.Size([1840, 768])
# Saved tensor for image_id 39208 at ../image_tensors/39208.pt with shape torch.Size([1090, 768])
# Saved tensor for image_id 39252 at ../image_tensors/39252.pt with shape torch.Size([1836, 768])
# Saved tensor for image_id 39255 at ../image_tensors/39255.pt with shape torch.Size([3132, 768])
# Saved tensor for image_id 39258 at ../image_tensors/39258.pt with shape torch.Size([2567, 768])
# Saved tensor for image_id 39269 at ../image_tensors/39269.pt with shape torch.Size([654, 768])
# Saved tensor for image_id 39297 at ../image_tensors/39297.pt with shape torch.Size([1624, 768])
# Saved tensor for image_id 39365 at ../image_tensors/39365.pt with shape torch.Size([689, 768])
# Saved tensor for image_id 39425 at ../image_tensors/39425.pt with shape torch.Size([2231, 768])
# Saved tensor for image_id 39466 at ../image_tensors/39466.pt with shape torch.Size([1809, 768])
# Saved tensor for image_id 39728 at ../image_tensors/39728.pt with shape torch.Size([896, 768])
# Saved tensor for image_id 39872 at ../image_tensors/39872.pt with shape torch.Size([2721, 768])
# Saved tensor for image_id 39880 at ../image_tensors/39880.pt with shape torch.Size([1306, 768])
# Saved tensor for image_id 39893 at ../image_tensors/39893.pt with shape torch.Size([2866, 768])
# Saved tensor for image_id 39990 at ../image_tensors/39990.pt with shape torch.Size([1045, 768])
# Saved tensor for image_id 40079 at ../image_tensors/40079.pt with shape torch.Size([728, 768])
# Saved tensor for image_id 40124 at ../image_tensors/40124.pt with shape torch.Size([1773, 768])
# Saved tensor for image_id 40129 at ../image_tensors/40129.pt with shape torch.Size([1028, 768])
# Saved tensor for image_id 40503 at ../image_tensors/40503.pt with shape torch.Size([1066, 768])
# Saved tensor for image_id 40639 at ../image_tensors/40639.pt with shape torch.Size([448, 768])
# Saved tensor for image_id 40864 at ../image_tensors/40864.pt with shape torch.Size([16, 768])
# Saved tensor for image_id 40888 at ../image_tensors/40888.pt with shape torch.Size([2673, 768])
# Saved tensor for image_id 41099 at ../image_tensors/41099.pt with shape torch.Size([442, 768])
# Saved tensor for image_id 41361 at ../image_tensors/41361.pt with shape torch.Size([1074, 768])
# Saved tensor for image_id 41368 at ../image_tensors/41368.pt with shape torch.Size([20, 768])
# Saved tensor for image_id 41586 at ../image_tensors/41586.pt with shape torch.Size([13, 768])

# %%
# import torch
# import os

# save_folder = '../image_tensors'
# image_id = 'your_image_id'  # replace with the actual image_id you want to load

# # Construct the path to the file
# load_path = os.path.join(save_folder, f"{image_id}.pt")

# # Check if the file exists
# if os.path.exists(load_path):
#     # Load the tensor from the file
#     loaded_tensor = torch.load(load_path)
#     print(f"Loaded tensor for image_id {image_id} from {load_path}")

#     # You can now use loaded_tensor as needed in your code
#     # For example, print its shape
#     print("Shape of the loaded tensor:", loaded_tensor.shape)
# else:
#     print(f"No saved tensor found for image_id {image_id} at {load_path}")
