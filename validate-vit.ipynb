# %%
import torch
import torch.nn as nn

config = {
    'image_size': 224,
    'patch_size': 32,
    'num_classes': 5,
    'dim': 768,
    'depth': 12,
    'heads': 12,
    'mlp_dim': 3072
}

class PatchEmbedding(nn.Module):
    def __init__(self, in_channels=3, patch_size=16, emb_size=768):
        super().__init__()
        self.patch_embed = nn.Conv2d(in_channels, emb_size, kernel_size=patch_size, stride=patch_size)
    
    def forward(self, x):
        x = self.patch_embed(x)  # [B, C, H, W]
        x = x.flatten(2)  # [B, C, H*W]
        x = x.transpose(1, 2)  # [B, H*W, C]
        return x

class Attention(nn.Module):
    def __init__(self, dim, heads=12):
        super().__init__()
        self.heads = heads
        self.scale = dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3)
        self.proj = nn.Linear(dim, dim)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.heads, C // self.heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv.unbind(0)   # make torchscript happy (cannot use tensor as tuple)

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)

        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        x = self.proj(x)
        return x

class MLP(nn.Module):
    def __init__(self, in_features, hidden_features, out_features, p=0.1):
        super().__init__()
        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_features, out_features)
        self.drop = nn.Dropout(p)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        x = self.drop(x)
        return x

class Block(nn.Module):
    def __init__(self, dim, heads, mlp_ratio=4., qkv_bias=True, p=0., attn_p=0.):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim, eps=1e-6)
        self.attn = Attention(dim, heads=heads)
        self.drop_path = nn.Dropout(p)
        self.norm2 = nn.LayerNorm(dim, eps=1e-6)
        self.mlp = MLP(in_features=dim, hidden_features=int(dim * mlp_ratio), out_features=dim)
        self.mlp_drop = nn.Dropout(p)

    def forward(self, x):
        x = x + self.drop_path(self.attn(self.norm1(x)))
        x = x + self.mlp_drop(self.mlp(self.norm2(x)))
        return x

class VisionTransformer(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.patch_embed = PatchEmbedding(patch_size=config['patch_size'], emb_size=config['dim'])
        self.cls_token = nn.Parameter(torch.zeros(1, 1, config['dim']))
        self.pos_embed = nn.Parameter(torch.zeros(1, (config['image_size'] // config['patch_size']) ** 2 + 1, config['dim']))
        self.pos_drop = nn.Dropout(p=0.1)

        self.blocks = nn.Sequential(*[Block(dim=config['dim'], heads=config['heads']) for _ in range(config['depth'])])
        self.norm = nn.LayerNorm(config['dim'], eps=1e-6)
        self.head = nn.Linear(config['dim'], config['num_classes'])

    def forward(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)

        x = self.blocks(x)
        x = self.norm(x)

        cls_token_final = x[:, 0]
        x = self.head(cls_token_final)

        return x

# %%
import pandas as pd
import os

def get_image_path(image_id:int):
    return os.path.join("tiles", str(image_id))

val = pd.read_csv("train-no-tma.csv")

val['tile_path'] = val['image_id'].apply(lambda x: get_image_path(x))

val.head()
# Out:
#    image_id label  image_width  image_height  is_tma    tile_path
# 0     38366  LGSC        31951         21718   False  tiles/38366
# 1     63298  HGSC        26067         20341   False  tiles/63298
# 2     54928    CC        36166         31487   False  tiles/54928
# 3     18813    CC        54671         32443   False  tiles/18813
# 4     63429    EC        67783         29066   False  tiles/63429

# %%
import os

def count_files(directory):
    if not os.path.exists(directory):
        return "The specified directory does not exist"
    
    if not os.path.isdir(directory):
        return "The specified path is not a directory"
    
    file_count = 0
    for _, _, files in os.walk(directory):
        file_count += len(files)
        
    return file_count

# %%
import os
from PIL import Image, ImageFile
import torch
from transformers import CLIPProcessor, CLIPModel
import pandas as pd
import torchvision.transforms as transforms
import random
import math
import numpy as np
from scipy.stats import entropy


# Define the paths
model_weights_path = "vit-non-tma-models-pt-2/model_step_29000.pt"  # Path to the model weights

# Set up the device and the model
device = "cuda" if torch.cuda.is_available() else "cpu"
device = "cpu"

model = VisionTransformer(config)
model.to(device)

# Load the weights
state_dict = torch.load(model_weights_path, map_location=device)
model.load_state_dict(state_dict, strict=False)

integer_to_label = {
    0: 'HGSC',
    1: 'CC',
    2: 'EC',
    3: 'LGSC',
    4: 'MC',
}

label_to_integer = {
    'HGSC': 0,
    'CC': 1,
    'EC': 2,
    'LGSC': 3,
    'MC': 4,
}

# Define a transformation to resize images to 224x224
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.8265, 0.7217, 0.8247], std=[0.1133, 0.1265, 0.0960]), # FOR NO TMA. calculated above
])

def process_sub_images(path):
    print('combing through this many files:', count_files(path))
    predicted_index_counts = {0: 0, 1: 0, 2: 0, 3: 0, 4: 0}
    probabilities = np.zeros(5)

    # Get all .png files from the directory
    all_files = [f for f in os.listdir(path) if f.lower().endswith('.png')]
    
    # Randomly select 100 files if there are more than 100, else select all
    sample_size = min(100, len(all_files))
    sampled_files = random.sample(all_files, sample_size)

    for image_name in sampled_files:
        image_path = os.path.join(path, image_name)
        sub_image = Image.open(image_path)

        sub_image = transform(sub_image).unsqueeze(0).to(device)

        outputs = model(sub_image)
        probs = outputs.softmax(dim=1)
        predicted_index = outputs.argmax(dim=1).item()

        predicted_index_counts[predicted_index] += 1
        probabilities += probs.cpu().detach().numpy()[0]

    index_probabilities = np.array(list(predicted_index_counts.values()))
    print(predicted_index_counts)
    print(probabilities)
    print(index_probabilities / index_probabilities.sum(), entropy(index_probabilities + 1e-8))
    print(probabilities / probabilities.sum(), entropy(probabilities))
    
    # Return label with highest probability
    return integer_to_label[probabilities.argmax()]

#     # Find the index with the highest count
#     highest_index = max(predicted_index_counts, key=predicted_index_counts.get)
    
#     # Return the label associated with the highest index
#     return integer_to_label[highest_index]


# Sort the dataframe by 'label' to ensure the order of categories.
sorted_val = val.sort_values('label')

# This will keep track of the indexes for each label type as you iterate through them.
label_indices = {label: iter(rows.index) for label, rows in sorted_val.groupby('label')}

total = 0
total_correct = 0
done = False

while not done:
    for label in ['HGSC', 'CC', 'EC', 'LGSC', 'MC']:
        try:
            # Try to get the next index for the current label
            index = next(label_indices[label])
            row = sorted_val.loc[index]
            predicted_label = process_sub_images(row.tile_path)
            is_correct = predicted_label == row.label
            total_correct += is_correct
            total += 1
            print(f"{total} Image ID: {row['image_id']} True Label: {row.label} Correct? {is_correct} Accuracy: {total_correct / total}")
        except StopIteration:
            # If there are no more items in the current label, break out of the loop.
            done = True
            break
# Out:
# combing through this many files: 20675
# {0: 15, 1: 20, 2: 28, 3: 4, 4: 33}
# [19.74587366 20.86293369 24.56795904 12.36310356 22.46012924]
# [0.15 0.2  0.28 0.04 0.33] 1.4574996687161268
# [0.19745874 0.20862934 0.24567959 0.12363104 0.22460129] 1.5860237269354076
# 1 Image ID: 65533 True Label: HGSC Correct? False Accuracy: 0.0
# combing through this many files: 37500
# {0: 2, 1: 0, 2: 90, 3: 1, 4: 7}
# [11.26259083 13.83724283 44.72092406 15.24236908 14.93687293]
# [0.02 0.   0.9  0.01 0.07] 0.40526483197391594
# [0.11262591 0.13837243 0.44720924 0.15242369 0.14936873] 1.4502185360090978
# 2 Image ID: 12442 True Label: CC Correct? False Accuracy: 0.0
# combing through this many files: 29739
# {0: 11, 1: 46, 2: 30, 3: 0, 4: 13}
# [19.7698997  25.05053087 22.91280146 13.34640963 18.92035869]
# [0.11 0.46 0.3  0.   0.13] 1.2264240350388134
# [0.197699   0.25050531 0.22912801 0.1334641  0.18920359] 1.5886519462386441
# 3 Image ID: 60936 True Label: EC Correct? False Accuracy: 0.0
# combing through this many files: 17893
# {0: 4, 1: 0, 2: 79, 3: 0, 4: 17}
# [13.98311106 15.17963054 39.42228864 14.02647041 17.38849973]
# [0.04 0.   0.79 0.   0.17] 0.6162083446245135
# [0.13983111 0.1517963  0.39422288 0.1402647  0.173885  ] 1.507918225388143
# 4 Image ID: 9183 True Label: LGSC Correct? False Accuracy: 0.0
# combing through this many files: 27234
# {0: 4, 1: 0, 2: 72, 3: 4, 4: 20}
# [14.57355149 14.88246292 38.95286905 12.79133195 18.79978465]
# [0.04 0.   0.72 0.04 0.2 ] 0.8159205795283363
# [0.14573551 0.14882463 0.38952869 0.12791332 0.18799785] 1.5086912580879357
# 5 Image ID: 51893 True Label: MC Correct? False Accuracy: 0.0
# combing through this many files: 21640
# {0: 8, 1: 35, 2: 33, 3: 1, 4: 23}
# [18.57335734 23.1316897  26.47181845 12.23457828 19.58855674]
# [0.08 0.35 0.33 0.01 0.23] 1.319431876600957
# [0.18573357 0.2313169  0.26471818 0.12234578 0.19588557] 1.5795202950653837
# 6 Image ID: 28121 True Label: HGSC Correct? False Accuracy: 0.0
# combing through this many files: 19433
# {0: 10, 1: 3, 2: 33, 3: 1, 4: 53}
# [21.81949493 15.90716615 25.61774329  7.97634812 28.67924707]
# [0.1  0.03 0.33 0.01 0.53] 1.0838510992359405
# [0.21819495 0.15907166 0.25617743 0.07976348 0.28679247] 1.5333941155276833
# 7 Image ID: 17067 True Label: CC Correct? False Accuracy: 0.0
# combing through this many files: 8642
# {0: 0, 1: 2, 2: 94, 3: 0, 4: 4}
# [ 9.08149169 14.56137332 45.14143544 20.70014267 10.51555678]
# [0.   0.02 0.94 0.   0.04] 0.2651583779901615
# [0.09081492 0.14561373 0.45141435 0.20700143 0.10515557] 1.4203450470240926
# 8 Image ID: 17487 True Label: EC Correct? True Accuracy: 0.125
# combing through this many files: 5875
# {0: 2, 1: 3, 2: 66, 3: 24, 4: 5}
# [13.46692431 15.7418536  32.04315948 24.74697899 14.00108445]
# [0.02 0.03 0.66 0.24 0.05] 0.9499719298249049
# [0.13466924 0.15741853 0.32043159 0.24746979 0.14001084] 1.5465741698274909
# 9 Image ID: 13387 True Label: LGSC Correct? False Accuracy: 0.1111111111111111
# combing through this many files: 11473
# {0: 2, 1: 0, 2: 69, 3: 0, 4: 29}
# [14.63216388 15.21596881 36.61164139 14.68773336 18.85249254]
# [0.02 0.   0.69 0.   0.29] 0.6932579685193432
# [0.14632164 0.15215969 0.36611641 0.14687733 0.18852493] 1.5318802461764458
# 10 Image ID: 48550 True Label: MC Correct? False Accuracy: 0.1
# combing through this many files: 12773
# {0: 2, 1: 6, 2: 82, 3: 5, 4: 5}
# [14.23045875 18.41456398 36.7514009  18.41850625 12.18507025]
# [0.02 0.06 0.82 0.05 0.05] 0.7093481011599725
# [0.14230459 0.18414564 0.36751401 0.18418506 0.1218507 ] 1.525019936003238
# 11 Image ID: 39990 True Label: HGSC Correct? False Accuracy: 0.09090909090909091
# combing through this many files: 2830
# {0: 3, 1: 0, 2: 72, 3: 4, 4: 21}
# [14.27957033 14.9015546  39.1979575  15.77020257 15.85071596]
# [0.03 0.   0.72 0.04 0.21] 0.798210728134712
# [0.1427957  0.14901554 0.39197957 0.15770202 0.15850716] 1.5119636798509144
# 12 Image ID: 3191 True Label: CC Correct? False Accuracy: 0.08333333333333333
# combing through this many files: 6979
# {0: 15, 1: 12, 2: 36, 3: 5, 4: 32}
# [20.74409513 19.23218064 25.71995653 11.43984816 22.86391937]
# [0.15 0.12 0.36 0.05 0.32] 1.421199655693203
# [0.20744095 0.19232181 0.25719957 0.11439848 0.22863919] 1.5780025214242592
# 13 Image ID: 34690 True Label: EC Correct? True Accuracy: 0.15384615384615385
# combing through this many files: 4967
# {0: 3, 1: 7, 2: 65, 3: 2, 4: 23}
# [16.78593089 16.43615212 30.63431098 12.42748795 23.71611907]
# [0.03 0.07 0.65 0.02 0.23] 0.9876197688911289
# [0.16785931 0.16436152 0.30634311 0.12427488 0.23716119] 1.5591950440136684
# 14 Image ID: 12244 True Label: LGSC Correct? False Accuracy: 0.14285714285714285
# combing through this many files: 50348
# {0: 2, 1: 2, 2: 49, 3: 3, 4: 44}
# [19.1663834  15.32507911 29.18624011 10.21728797 26.10500989]
# [0.02 0.02 0.49 0.03 0.44] 0.9724505459076765
# [0.19166383 0.15325079 0.2918624  0.10217288 0.2610501 ] 1.547167921164859
# 15 Image ID: 47431 True Label: MC Correct? False Accuracy: 0.13333333333333333
# combing through this many files: 9676
# {0: 17, 1: 2, 2: 8, 3: 3, 4: 70}
# [22.86275563 15.17241056 22.94423578  8.32671443 30.69388332]
# [0.17 0.02 0.08 0.03 0.7 ] 0.9364006131974482
# [0.22862756 0.15172411 0.22944236 0.08326714 0.30693883] 1.5307492936331315
# 16 Image ID: 30539 True Label: HGSC Correct? False Accuracy: 0.125
# combing through this many files: 47828
# {0: 0, 1: 0, 2: 92, 3: 1, 4: 7}
# [ 9.61878392 12.83931725 44.61021066 18.74512117 14.18656723]
# [0.   0.   0.92 0.01 0.07] 0.30891099005459816
# [0.09618784 0.12839317 0.44610211 0.18745121 0.14186567] 1.439747015496177
# 17 Image ID: 51346 True Label: CC Correct? False Accuracy: 0.11764705882352941
# combing through this many files: 15785
# {0: 3, 1: 6, 2: 67, 3: 7, 4: 17}
# [16.58523728 19.36008587 30.7236688  16.25645686 17.07455146]
# [0.03 0.06 0.67 0.07 0.17] 1.029702215859304
# [0.16585237 0.19360086 0.30723669 0.16256457 0.17074551] 1.5755797580798165
# 18 Image ID: 4608 True Label: EC Correct? True Accuracy: 0.16666666666666666
# combing through this many files: 15259
# {0: 12, 1: 9, 2: 33, 3: 0, 4: 46}
# [21.01754788 18.06945974 24.09300087  8.93065754 27.88933386]
# [0.12 0.09 0.33 0.   0.46] 1.1942086408311703
# [0.21017548 0.1806946  0.24093001 0.08930658 0.27889334] 1.551758800898815
# 19 Image ID: 10252 True Label: LGSC Correct? False Accuracy: 0.15789473684210525
# combing through this many files: 31173
# {0: 1, 1: 0, 2: 62, 3: 0, 4: 37}
# [17.11070416 14.91757669 33.21269858 11.58535371 23.17366656]
# [0.01 0.   0.62 0.   0.37] 0.710307244639534
# [0.17110704 0.14917577 0.33212699 0.11585354 0.23173667] 1.5405415178220507
# 20 Image ID: 25331 True Label: MC Correct? False Accuracy: 0.15
# combing through this many files: 27164
# {0: 6, 1: 4, 2: 43, 3: 4, 4: 43}
# [18.32590804 15.61652315 27.81628156 14.05532372 24.18596336]
# [0.06 0.04 0.43 0.04 0.43] 1.1521289699661987
# [0.18325908 0.15616523 0.27816282 0.14055324 0.24185963] 1.5759450039105631
# 21 Image ID: 15209 True Label: HGSC Correct? False Accuracy: 0.14285714285714285
# combing through this many files: 8133
# {0: 2, 1: 0, 2: 82, 3: 1, 4: 15}
# [13.03839273 14.74793001 40.32677223 15.79877913 16.08812601]
# [0.02 0.   0.82 0.01 0.15] 0.5715899326329399
# [0.13038393 0.1474793  0.40326772 0.15798779 0.16088126] 1.4996116134737827
# 22 Image ID: 14051 True Label: CC Correct? False Accuracy: 0.13636363636363635
# combing through this many files: 624
# {0: 2, 1: 7, 2: 69, 3: 10, 4: 12}
# [13.60401414 18.07179428 31.66328622 20.13102603 16.52987907]
# [0.02 0.07 0.69 0.1  0.12] 1.0051127371309103
# [0.13604014 0.18071794 0.31663286 0.20131026 0.16529879] 1.564900506928133
# 23 Image ID: 51215 True Label: EC Correct? True Accuracy: 0.17391304347826086
# combing through this many files: 20260
# {0: 1, 1: 2, 2: 79, 3: 2, 4: 16}
# [14.59051769 16.07960456 39.35471699 13.1553915  16.81976895]
# [0.01 0.02 0.79 0.02 0.16] 0.6819663008671504
# [0.14590518 0.16079605 0.39354717 0.13155392 0.16819769] 1.5083836391517114
# 24 Image ID: 6898 True Label: LGSC Correct? False Accuracy: 0.16666666666666666
# combing through this many files: 18250
# {0: 2, 1: 7, 2: 48, 3: 15, 4: 28}
# [15.02791578 18.27917523 30.76178512 17.95549201 17.97563203]
# [0.02 0.07 0.48 0.15 0.28] 1.2576922541115318
# [0.15027916 0.18279175 0.30761785 0.17955492 0.17975632] 1.5749400526538917
# 25 Image ID: 3997 True Label: MC Correct? False Accuracy: 0.16
# combing through this many files: 6842
# {0: 5, 1: 9, 2: 59, 3: 8, 4: 19}
# [17.31628881 19.26717    30.85202363 15.85319075 16.71132723]
# [0.05 0.09 0.59 0.08 0.19] 1.1954022575398175
# [0.17316289 0.1926717  0.30852024 0.15853191 0.16711327] 1.5747039723355227
# 26 Image ID: 15221 True Label: HGSC Correct? False Accuracy: 0.15384615384615385
# combing through this many files: 33314
# {0: 6, 1: 2, 2: 42, 3: 3, 4: 47}
# [18.79400679 14.82763575 29.04411867 11.80910161 25.52513658]
# [0.06 0.02 0.42 0.03 0.47] 1.0714526937301487
# [0.18794007 0.14827636 0.29044119 0.11809102 0.25525137] 1.557091766760229
# 27 Image ID: 4877 True Label: CC Correct? False Accuracy: 0.14814814814814814
# combing through this many files: 38877
# {0: 10, 1: 7, 2: 15, 3: 0, 4: 68}
# [22.1429403  17.76044244 21.83427723  7.31681239 30.94552794]
# [0.1  0.07 0.15 0.   0.68] 0.9632251992151661
# [0.2214294  0.17760442 0.21834277 0.07316812 0.30945528] 1.52733083709448
# 28 Image ID: 50304 True Label: EC Correct? False Accuracy: 0.14285714285714285
# combing through this many files: 12955
# {0: 17, 1: 8, 2: 18, 3: 2, 4: 55}
# [23.26660253 17.32037158 22.41980269  7.75856971 29.23465261]
# [0.17 0.08 0.18 0.02 0.55] 1.219005482696512
# [0.23266603 0.17320372 0.22419803 0.0775857  0.29234653] 1.5360348614195154
# 29 Image ID: 2391 True Label: LGSC Correct? False Accuracy: 0.13793103448275862
# combing through this many files: 27111
# {0: 0, 1: 0, 2: 92, 3: 1, 4: 7}
# [ 9.43883593 13.03690606 46.98381917 16.3691471  14.17129225]
# [0.   0.   0.92 0.01 0.07] 0.30891099005459816
# [0.09438836 0.13036906 0.46983819 0.16369147 0.14171292] 1.4164451631561916
# 30 Image ID: 37307 True Label: MC Correct? False Accuracy: 0.13333333333333333
# combing through this many files: 13490
# {0: 1, 1: 5, 2: 76, 3: 8, 4: 10}
# [14.20734774 16.5793488  36.13607377 17.99275088 15.08447878]
# [0.01 0.05 0.76 0.08 0.1 ] 0.8367271199669851
# [0.14207348 0.16579349 0.36136074 0.17992751 0.15084479] 1.5369334007272766
# 31 Image ID: 11417 True Label: HGSC Correct? False Accuracy: 0.12903225806451613
# combing through this many files: 26361
# {0: 19, 1: 9, 2: 45, 3: 0, 4: 27}
# [21.95870866 17.68647604 27.79219662  9.97433768 22.58828127]
# [0.19 0.09 0.45 0.   0.27] 1.2451024961660808
# [0.21958709 0.17686476 0.27792197 0.09974338 0.22588281] 1.5611245997279548
# 32 Image ID: 61961 True Label: CC Correct? False Accuracy: 0.125
# combing through this many files: 6989
# {0: 1, 1: 3, 2: 71, 3: 16, 4: 9}
# [13.60579615 14.52373022 34.30640115 22.38539666 15.17867545]
# [0.01 0.03 0.71 0.16 0.09] 0.9043446979273917
# [0.13605796 0.1452373  0.34306401 0.22385397 0.15178676] 1.5398494786138461
# 33 Image ID: 25604 True Label: EC Correct? True Accuracy: 0.15151515151515152
# combing through this many files: 14615
# {0: 17, 1: 17, 2: 46, 3: 1, 4: 19}
# [20.19843365 19.06586764 28.06039526 10.41863533 22.25666796]
# [0.17 0.17 0.46 0.01 0.19] 1.3212592009803752
# [0.20198434 0.19065868 0.28060395 0.10418635 0.22256668] 1.5656926439121441
# 34 Image ID: 23796 True Label: LGSC Correct? False Accuracy: 0.14705882352941177
# combing through this many files: 13764
# {0: 7, 1: 4, 2: 65, 3: 3, 4: 21}
# [16.66706135 16.71639825 34.3584     13.86714915 18.39099133]
# [0.07 0.04 0.65 0.03 0.21] 1.0278448957189876
# [0.16667061 0.16716398 0.343584   0.13867149 0.18390991] 1.5500905524920285
# 35 Image ID: 57265 True Label: MC Correct? False Accuracy: 0.14285714285714285
# combing through this many files: 19792
# {0: 0, 1: 0, 2: 93, 3: 3, 4: 4}
# [ 7.73678738 13.06203603 44.7935248  25.07765751  9.32999449]
# [0.   0.   0.93 0.03 0.04] 0.3014425195849737
# [0.07736787 0.13062036 0.44793525 0.25077657 0.09329994] 1.3917847371902106
# 36 Image ID: 5251 True Label: HGSC Correct? False Accuracy: 0.1388888888888889
# combing through this many files: 16594
# {0: 3, 1: 1, 2: 59, 3: 0, 4: 37}
# [15.65251705 15.07618879 35.76473719 11.0186995  22.48785745]
# [0.03 0.01 0.59 0.   0.37] 0.8304251006960444
# [0.15652517 0.15076189 0.35764737 0.110187   0.22487857] 1.521855776551872
# 37 Image ID: 11263 True Label: CC Correct? False Accuracy: 0.13513513513513514
# combing through this many files: 11648
# {0: 17, 1: 6, 2: 27, 3: 3, 4: 47}
# [22.65526055 17.10832564 24.760473    9.36127703 26.11466414]
# [0.17 0.06 0.27 0.03 0.47] 1.2836146544337326
# [0.2265526  0.17108326 0.24760473 0.09361277 0.26114664] 1.5564473137148687
# 38 Image ID: 59900 True Label: EC Correct? False Accuracy: 0.13157894736842105
# combing through this many files: 10948
# {0: 10, 1: 11, 2: 49, 3: 5, 4: 25}
# [18.07315994 17.45091298 30.18976854 14.69075704 19.59540127]
# [0.1  0.11 0.49 0.05 0.25] 1.3189603990689474
# [0.1807316  0.17450913 0.30189769 0.14690757 0.19595401] 1.5765545651926018
# 39 Image ID: 8985 True Label: LGSC Correct? False Accuracy: 0.1282051282051282
# combing through this many files: 10100
# {0: 11, 1: 3, 2: 46, 3: 1, 4: 39}
# [19.97702864 15.33043689 28.78286737  9.94067753 25.96898884]
# [0.11 0.03 0.46 0.01 0.39] 1.118479253589156
# [0.19977029 0.15330437 0.28782868 0.09940678 0.25968989] 1.547318003439658
# 40 Image ID: 34508 True Label: MC Correct? False Accuracy: 0.125
# combing through this many files: 12920
# {0: 5, 1: 36, 2: 42, 3: 3, 4: 14}
# [18.08612783 24.39497426 26.37686883 15.25419656 15.88783208]
# [0.05 0.36 0.42 0.03 0.14] 1.2623838384415562
# [0.18086128 0.24394974 0.26376869 0.15254197 0.15887832] 1.5840621138140853
# 41 Image ID: 46139 True Label: HGSC Correct? False Accuracy: 0.12195121951219512
# combing through this many files: 22847
# {0: 0, 1: 0, 2: 88, 3: 3, 4: 9}
# [ 8.91291406 12.60663196 42.47757107 22.67019167 13.33269143]
# [0.   0.   0.88 0.03 0.09] 0.43440521381916786
# [0.08912914 0.12606632 0.42477571 0.22670192 0.13332691] 1.44535175522522
# 42 Image ID: 29915 True Label: CC Correct? False Accuracy: 0.11904761904761904
# combing through this many files: 12834
# {0: 2, 1: 6, 2: 71, 3: 0, 4: 21}
# [17.89200908 18.52124234 33.53395535 11.64060602 18.41218748]
# [0.02 0.06 0.71 0.   0.21] 0.817949252458424
# [0.17892009 0.18521242 0.33533955 0.11640606 0.18412187] 1.5485135475150327
# 43 Image ID: 11431 True Label: EC Correct? True Accuracy: 0.13953488372093023
# combing through this many files: 17647
# {0: 14, 1: 21, 2: 35, 3: 1, 4: 29}
# [20.96122035 20.61557461 25.38351917 10.79541117 22.24427458]
# [0.14 0.21 0.35 0.01 0.29] 1.3754648360568944
# [0.2096122  0.20615575 0.25383519 0.10795411 0.22244275] 1.5757510582746383
# 44 Image ID: 8130 True Label: LGSC Correct? False Accuracy: 0.13636363636363635
# combing through this many files: 13370
# {0: 8, 1: 15, 2: 33, 3: 2, 4: 42}
# [18.75594394 19.5348618  26.42506594 12.80090611 22.48322241]
# [0.08 0.15 0.33 0.02 0.42] 1.2950756542977866
# [0.18755944 0.19534862 0.26425066 0.12800906 0.22483222] 1.583271019052297
# 45 Image ID: 30868 True Label: MC Correct? False Accuracy: 0.13333333333333333
# combing through this many files: 14363
# {0: 6, 1: 7, 2: 45, 3: 1, 4: 41}
# [19.61349184 15.12675318 29.16229667 10.53383365 25.56362533]
# [0.06 0.07 0.45 0.01 0.41] 1.1258882402689767
# [0.19613492 0.15126753 0.29162296 0.10533834 0.25563625] 1.550319247518853
# 46 Image ID: 41361 True Label: HGSC Correct? False Accuracy: 0.13043478260869565
# combing through this many files: 17972
# {0: 2, 1: 1, 2: 74, 3: 1, 4: 22}
# [13.79838765 14.6299731  39.87263042 13.80969445 17.88931413]
# [0.02 0.01 0.74 0.01 0.22] 0.7262697347976022
# [0.13798388 0.14629973 0.39872631 0.13809694 0.17889314] 1.5023900527463372
# 47 Image ID: 56947 True Label: CC Correct? False Accuracy: 0.1276595744680851
# combing through this many files: 13623
# {0: 13, 1: 31, 2: 32, 3: 1, 4: 23}
# [19.33153692 22.85649136 26.59658885 12.08809859 19.12728447]
# [0.13 0.31 0.32 0.01 0.23] 1.3769915779221522
# [0.19331537 0.22856491 0.26596589 0.12088099 0.19127284] 1.5790805396003997
# 48 Image ID: 63367 True Label: EC Correct? True Accuracy: 0.14583333333333334
# combing through this many files: 11716
# {0: 7, 1: 23, 2: 33, 3: 5, 4: 32}
# [17.77356463 21.13982916 25.48424707 13.04901677 22.55334347]
# [0.07 0.23 0.33 0.05 0.32] 1.4044379263240165
# [0.17773564 0.21139829 0.25484247 0.13049017 0.22553343] 1.58556544163931
# 49 Image ID: 3672 True Label: LGSC Correct? False Accuracy: 0.14285714285714285
# combing through this many files: 4896
# {0: 10, 1: 30, 2: 30, 3: 7, 4: 23}
# [19.27510998 22.11710847 23.44831668 14.55012383 20.60934176]
# [0.1  0.3  0.3  0.07 0.23] 1.4768158677393561
# [0.1927511  0.22117108 0.23448317 0.14550124 0.20609342] 1.5971047821156166
# 50 Image ID: 48502 True Label: MC Correct? False Accuracy: 0.14
# combing through this many files: 13908
# {0: 11, 1: 18, 2: 47, 3: 1, 4: 23}
# [21.0473127  19.21676861 26.42100073 10.67004622 22.64487252]
# [0.11 0.18 0.47 0.01 0.23] 1.2904017475215226
# [0.21047313 0.19216768 0.26421001 0.10670046 0.22644872] 1.5717228136040602
# 51 Image ID: 50712 True Label: HGSC Correct? False Accuracy: 0.13725490196078433
# combing through this many files: 32917
# {0: 17, 1: 8, 2: 36, 3: 1, 4: 38}
# [20.35763413 17.94153265 27.27638382  9.86407832 24.56037134]
# [0.17 0.08 0.36 0.01 0.38] 1.2848190360707212
# [0.20357634 0.17941533 0.27276384 0.09864078 0.24560371] 1.5599562214472567
# 52 Image ID: 59515 True Label: CC Correct? False Accuracy: 0.1346153846153846
# combing through this many files: 31805
# {0: 18, 1: 3, 2: 3, 3: 0, 4: 76}
# [26.94899862 15.15200166 17.60313632  5.82520828 34.47065458]
# [0.18 0.03 0.03 0.   0.76] 0.7276291965680892
# [0.26948999 0.15152002 0.17603136 0.05825208 0.34470655] 1.477811598254818
# 53 Image ID: 7490 True Label: EC Correct? False Accuracy: 0.1320754716981132
# combing through this many files: 31728
# {0: 9, 1: 9, 2: 35, 3: 2, 4: 45}
# [19.64200204 16.41071902 27.2796775  10.77052863 25.89707283]
# [0.09 0.09 0.35 0.02 0.45] 1.2384368769768406
# [0.19642002 0.16410719 0.27279677 0.10770529 0.25897073] 1.5605102669631854
# 54 Image ID: 26862 True Label: LGSC Correct? False Accuracy: 0.12962962962962962
# combing through this many files: 19189
# {0: 7, 1: 32, 2: 33, 3: 2, 4: 26}
# [18.88334066 21.40967244 25.97880225 12.05272031 21.67546403]
# [0.07 0.32 0.33 0.02 0.26] 1.3451054482216769
# [0.18883341 0.21409673 0.25978802 0.1205272  0.21675464] 1.5813597621321365
# 55 Image ID: 28562 True Label: MC Correct? False Accuracy: 0.12727272727272726
# combing through this many files: 36464
# {0: 5, 1: 11, 2: 64, 3: 5, 4: 15}
# [15.77678356 19.0918335  32.13429402 17.3937585  15.60333004]
# [0.05 0.11 0.64 0.05 0.15] 1.1125652117192713
# [0.15776784 0.19091834 0.32134294 0.17393759 0.1560333 ] 1.566373735305035
# 56 Image ID: 19255 True Label: HGSC Correct? False Accuracy: 0.125
# combing through this many files: 20976
# {0: 3, 1: 4, 2: 76, 3: 2, 4: 15}
# [13.82635984 17.1975514  38.98829649 16.75105908 13.23673245]
# [0.03 0.04 0.76 0.02 0.15] 0.8053322313673457
# [0.1382636  0.17197552 0.38988297 0.16751059 0.13236733] 1.5105102711195302
# 57 Image ID: 38349 True Label: CC Correct? False Accuracy: 0.12280701754385964
# combing through this many files: 24074
# {0: 2, 1: 22, 2: 54, 3: 2, 4: 20}
# [17.77452327 20.65137206 28.57210672 13.27046983 19.73152828]
# [0.02 0.22 0.54 0.02 0.2 ] 1.144217119755629
# [0.17774523 0.20651372 0.28572107 0.1327047  0.19731528] 1.578971735578929
# 58 Image ID: 10246 True Label: EC Correct? True Accuracy: 0.13793103448275862
# combing through this many files: 11668
# {0: 10, 1: 5, 2: 28, 3: 2, 4: 55}
# [20.94221643 16.45126639 26.26856627  8.81690958 27.52104162]
# [0.1  0.05 0.28 0.02 0.55] 1.143526323265218
# [0.20942216 0.16451266 0.26268566 0.0881691  0.27521042] 1.5446761995912852
# 59 Image ID: 25256 True Label: LGSC Correct? False Accuracy: 0.13559322033898305
# combing through this many files: 25820
# {0: 1, 1: 1, 2: 84, 3: 1, 4: 13}
# [13.91779482 15.45022281 39.53731607 13.37483152 17.71983484]
# [0.01 0.01 0.84 0.01 0.13] 0.5498406598177963
# [0.13917795 0.15450223 0.39537316 0.13374832 0.17719835] 1.5055895017219751
# 60 Image ID: 49587 True Label: MC Correct? False Accuracy: 0.13333333333333333
# combing through this many files: 6343
# {0: 4, 1: 3, 2: 77, 3: 6, 4: 10}
# [14.82248927 17.50538658 32.67530925 17.69127104 17.30554426]
# [0.04 0.03 0.77 0.06 0.1 ] 0.8342657913959746
# [0.14822489 0.17505387 0.32675309 0.17691271 0.17305544] 1.5635087661515374
# 61 Image ID: 12159 True Label: HGSC Correct? False Accuracy: 0.13114754098360656
# combing through this many files: 16352
# {0: 10, 1: 8, 2: 37, 3: 6, 4: 39}
# [19.26573025 17.90766267 27.0729789  12.89100264 22.86262606]
# [0.1  0.08 0.37 0.06 0.39] 1.336222115821339
# [0.1926573  0.17907663 0.27072979 0.12891003 0.22862626] 1.580488732876013
# 62 Image ID: 25928 True Label: CC Correct? False Accuracy: 0.12903225806451613
# combing through this many files: 20832
# {0: 4, 1: 29, 2: 28, 3: 1, 4: 38}
# [19.65287122 21.83701988 24.65040334 11.23588562 22.62381991]
# [0.04 0.29 0.28 0.01 0.38] 1.2579026178034303
# [0.19652871 0.2183702  0.24650403 0.11235886 0.2262382 ] 1.579055059513146
# 63 Image ID: 38118 True Label: EC Correct? True Accuracy: 0.14285714285714285
# combing through this many files: 26619
# {0: 2, 1: 6, 2: 61, 3: 1, 4: 30}
# [18.71441495 17.04462089 30.46504447  9.42508517 24.35083411]
# [0.02 0.06 0.61 0.01 0.3 ] 0.9558094034038254
# [0.18714415 0.17044621 0.30465045 0.09425085 0.24350834] 1.5438935949599049
# 64 Image ID: 21303 True Label: LGSC Correct? False Accuracy: 0.140625
# combing through this many files: 28607
# {0: 0, 1: 0, 2: 85, 3: 1, 4: 14}
# [10.48654955 12.77927095 45.20796572 17.8077707  13.71844324]
# [0.   0.   0.85 0.01 0.14] 0.4594485970740123
# [0.1048655  0.12779271 0.45207966 0.17807771 0.13718443] 1.4380846657954347
# 65 Image ID: 2227 True Label: MC Correct? False Accuracy: 0.13846153846153847
# combing through this many files: 29216
# {0: 3, 1: 25, 2: 50, 3: 2, 4: 20}
# [17.66931358 21.56908718 29.90936829 14.57311485 16.27911596]
# [0.03 0.25 0.5  0.02 0.2 ] 1.198471960586438
# [0.17669314 0.21569087 0.29909368 0.14573115 0.16279116] 1.5743148932057767
# 66 Image ID: 17416 True Label: HGSC Correct? False Accuracy: 0.13636363636363635
# combing through this many files: 25090
# {0: 11, 1: 4, 2: 45, 3: 1, 4: 39}
# [21.35601131 16.54319919 27.51903924  9.0044119  25.57733864]
# [0.11 0.04 0.45 0.01 0.39] 1.1441627697533312
# [0.21356011 0.16543199 0.27519039 0.09004412 0.25577339] 1.5479372715808621
# 67 Image ID: 6359 True Label: CC Correct? False Accuracy: 0.13432835820895522
# combing through this many files: 8802
# {0: 10, 1: 17, 2: 37, 3: 6, 4: 30}
# [18.21856289 20.17494205 26.80913458 14.27316113 20.52419924]
# [0.1  0.17 0.37 0.06 0.3 ] 1.4293609980623745
# [0.18218563 0.20174942 0.26809135 0.14273161 0.20524199] 1.5889642414135832
# 68 Image ID: 22924 True Label: EC Correct? True Accuracy: 0.14705882352941177
# combing through this many files: 14217
# {0: 5, 1: 6, 2: 70, 3: 4, 4: 15}
# [17.27321327 16.88967283 33.53101394 13.48096315 18.82513659]
# [0.05 0.06 0.7  0.04 0.15] 0.9815867488054126
# [0.17273213 0.16889673 0.33531014 0.13480963 0.18825137] 1.5546098690606729
# 69 Image ID: 5852 True Label: LGSC Correct? False Accuracy: 0.14492753623188406
# combing through this many files: 19049
# {0: 10, 1: 0, 2: 10, 3: 1, 4: 79}
# [23.45778526 14.63773413 21.64888369  7.21257368 33.04302412]
# [0.1  0.   0.1  0.01 0.79] 0.6927893669411319
# [0.23457785 0.14637734 0.21648884 0.07212574 0.33043024] 1.5082275337778304
# 70 Image ID: 14532 True Label: MC Correct? True Accuracy: 0.15714285714285714
# combing through this many files: 18140
# {0: 0, 1: 1, 2: 84, 3: 3, 4: 12}
# [10.34197298 13.89012033 42.43872219 21.41210562 11.91707953]
# [0.   0.01 0.84 0.03 0.12] 0.5521369114922557
# [0.10341973 0.1389012  0.42438722 0.21412105 0.11917079] 1.4560973314401755
# 71 Image ID: 16209 True Label: HGSC Correct? False Accuracy: 0.15492957746478872
# combing through this many files: 23372
# {0: 9, 1: 36, 2: 27, 3: 2, 4: 26}
# [18.98010356 22.90967267 23.66049881 14.143338   20.30638751]
# [0.09 0.36 0.27 0.02 0.26] 1.366509159182227
# [0.18980103 0.22909673 0.23660499 0.14143338 0.20306387] 1.5944053132482383
# 72 Image ID: 42125 True Label: CC Correct? False Accuracy: 0.1527777777777778
# combing through this many files: 36583
# {0: 14, 1: 6, 2: 12, 3: 1, 4: 67}
# [23.64072638 16.2094102  21.18127324  7.82173387 31.14685683]
# [0.14 0.06 0.12 0.01 0.67] 1.0128637394058764
# [0.23640726 0.1620941  0.21181273 0.07821734 0.31146857] 1.5272668784147148
# 73 Image ID: 15742 True Label: EC Correct? False Accuracy: 0.1506849315068493
# combing through this many files: 4546
# {0: 7, 1: 23, 2: 51, 3: 4, 4: 15}
# [17.47157159 21.19821758 28.90766789 14.57125357 17.85128944]
# [0.07 0.23 0.51 0.04 0.15] 1.2809024289423583
# [0.17471572 0.21198218 0.28907668 0.14571254 0.17851289] 1.5806629813580146
# 74 Image ID: 281 True Label: LGSC Correct? False Accuracy: 0.14864864864864866
# combing through this many files: 26213
# {0: 3, 1: 0, 2: 69, 3: 0, 4: 28}
# [16.51413437 15.23654327 35.99194109 10.97946993 21.27791062]
# [0.03 0.   0.69 0.   0.28] 0.7176610712682804
# [0.16514134 0.15236543 0.35991941 0.1097947  0.21277911] 1.5237041207050286
# 75 Image ID: 4797 True Label: MC Correct? False Accuracy: 0.14666666666666667
# combing through this many files: 12099
# {0: 2, 1: 14, 2: 52, 3: 11, 4: 21}
# [15.88436499 20.40027857 29.60699178 17.39281298 16.71555303]
# [0.02 0.14 0.52 0.11 0.21] 1.2640742910366358
# [0.15884365 0.20400278 0.29606991 0.17392813 0.16715553] 1.580130575207122
# 76 Image ID: 35998 True Label: HGSC Correct? False Accuracy: 0.14473684210526316
# combing through this many files: 12792
# {0: 7, 1: 9, 2: 47, 3: 0, 4: 37}
# [18.70426432 16.45935127 30.50209048 10.92446017 23.4098337 ]
# [0.07 0.09 0.47 0.   0.37] 1.1255972656333038
# [0.18704264 0.16459351 0.3050209  0.1092446  0.23409834] 1.5545078848493759
# 77 Image ID: 22290 True Label: CC Correct? False Accuracy: 0.14285714285714285
# combing through this many files: 29101
# {0: 2, 1: 0, 2: 89, 3: 3, 4: 6}
# [11.86375518 15.21057718 42.54031092 19.64788719 10.73746879]
# [0.02 0.   0.89 0.03 0.06] 0.4559569397110205
# [0.11863755 0.15210577 0.42540311 0.19647887 0.10737469] 1.462249382099042
# 78 Image ID: 60928 True Label: EC Correct? True Accuracy: 0.15384615384615385
# combing through this many files: 5822
# {0: 8, 1: 12, 2: 54, 3: 2, 4: 24}
# [18.26390524 18.68946394 30.72864804 14.82958035 17.48840267]
# [0.08 0.12 0.54 0.02 0.24] 1.2099788170948729
# [0.18263905 0.18689464 0.30728648 0.1482958  0.17488403] 1.574545599668312
# 79 Image ID: 38959 True Label: LGSC Correct? False Accuracy: 0.1518987341772152
# combing through this many files: 22517
# {0: 6, 1: 0, 2: 54, 3: 0, 4: 40}
# [16.91747554 14.71257653 34.35489661 10.89138716 23.1236637 ]
# [0.06 0.   0.54 0.   0.4 ] 0.8680614558498536
# [0.16917476 0.14712577 0.34354897 0.10891387 0.23123664] 1.5296984531961462
# 80 Image ID: 56117 True Label: MC Correct? False Accuracy: 0.15
# combing through this many files: 21109
# {0: 6, 1: 46, 2: 39, 3: 6, 4: 3}
# [17.58587384 24.8900531  26.11317827 17.60848856 13.80240593]
# [0.06 0.46 0.39 0.06 0.03] 1.1672365971466692
# [0.17585874 0.24890053 0.26113178 0.17608489 0.13802406] 1.5815866111892367
# 81 Image ID: 20316 True Label: HGSC Correct? False Accuracy: 0.14814814814814814
# combing through this many files: 12945
# {0: 15, 1: 6, 2: 33, 3: 2, 4: 44}
# [22.91602999 16.80055956 25.25634501  8.47900896 26.54805659]
# [0.15 0.06 0.33 0.02 0.44] 1.2587032102757725
# [0.2291603  0.1680056  0.25256345 0.08479009 0.26548057] 1.5461716029403032
# 82 Image ID: 38669 True Label: CC Correct? False Accuracy: 0.14634146341463414
# combing through this many files: 18673
# {0: 9, 1: 16, 2: 44, 3: 2, 4: 29}
# [19.34274732 20.55139114 26.73007061 13.4429951  19.93279615]
# [0.09 0.16 0.44 0.02 0.29] 1.3083836056051041
# [0.19342747 0.20551391 0.26730071 0.13442995 0.19932796] 1.586856048056322
# 83 Image ID: 52836 True Label: EC Correct? True Accuracy: 0.1566265060240964
# combing through this many files: 22430
# {0: 2, 1: 0, 2: 84, 3: 4, 4: 10}
# [10.78662417 13.42343608 45.32201666 17.37991679 13.08800585]
# [0.02 0.   0.84 0.04 0.1 ] 0.5837108506758223
# [0.10786624 0.13423436 0.45322017 0.17379917 0.13088006] 1.4387011718306906
# 84 Image ID: 39466 True Label: LGSC Correct? False Accuracy: 0.15476190476190477
# combing through this many files: 23768
# {0: 2, 1: 0, 2: 65, 3: 0, 4: 33}
# [16.81987241 15.1484315  34.86517131 10.76772716 22.39879687]
# [0.02 0.   0.65 0.   0.33] 0.7241080266490529
# [0.16819873 0.15148432 0.34865172 0.10767727 0.22398797] 1.5281867072516673
# 85 Image ID: 56351 True Label: MC Correct? False Accuracy: 0.15294117647058825
# combing through this many files: 22564
# {0: 0, 1: 0, 2: 90, 3: 3, 4: 7}
# [ 9.03588584 13.506467   45.35221082 20.743713   11.36172409]
# [0.   0.   0.9  0.03 0.07] 0.3861694088361408
# [0.09035886 0.13506467 0.4535221  0.20743713 0.11361724] 1.4196162289420042
# 86 Image ID: 29331 True Label: HGSC Correct? False Accuracy: 0.1511627906976744
# combing through this many files: 30303
# {0: 16, 1: 18, 2: 40, 3: 3, 4: 23}
# [21.69459429 19.69675496 24.8775576  11.38336693 22.34772601]
# [0.16 0.18 0.4  0.03 0.23] 1.4116152542772773
# [0.21694594 0.19696755 0.24877558 0.11383367 0.22347726] 1.579861626243208
# 87 Image ID: 56861 True Label: CC Correct? False Accuracy: 0.14942528735632185
# combing through this many files: 6419
# {0: 4, 1: 5, 2: 39, 3: 3, 4: 49}
# [19.2427108  17.44652833 26.98558478 10.9287248  25.39645066]
# [0.04 0.05 0.39 0.03 0.49] 1.1005071597841372
# [0.19242711 0.17446528 0.26985585 0.10928725 0.25396451] 1.5652352872890134
# 88 Image ID: 50962 True Label: EC Correct? True Accuracy: 0.1590909090909091
# combing through this many files: 8928
# {0: 12, 1: 2, 2: 23, 3: 1, 4: 62}
# [22.13638748 15.12259342 24.17805113  8.58763413 29.97533385]
# [0.12 0.02 0.23 0.01 0.62] 1.0131314567626224
# [0.22136387 0.15122593 0.24178051 0.08587634 0.29975334] 1.5346844209171984
# 89 Image ID: 38366 True Label: LGSC Correct? False Accuracy: 0.15730337078651685
# combing through this many files: 34256
# {0: 11, 1: 15, 2: 41, 3: 3, 4: 30}
# [20.50588082 19.96000651 26.64257176 11.45860382 21.43293748]
# [0.11 0.15 0.41 0.03 0.3 ] 1.3593120455984795
# [0.20505881 0.19960006 0.26642572 0.11458604 0.21432937] 1.5773027083668834
# 90 Image ID: 35792 True Label: MC Correct? False Accuracy: 0.15555555555555556
# combing through this many files: 6820
# {0: 8, 1: 6, 2: 74, 3: 5, 4: 7}
# [16.89370006 21.55803339 31.55350859 18.84718931 11.14756808]
# [0.08 0.06 0.74 0.05 0.07] 0.9296155201380745
# [0.168937   0.21558034 0.31553509 0.18847189 0.11147568] 1.5542600317826671
# 91 Image ID: 60058 True Label: HGSC Correct? False Accuracy: 0.15384615384615385
# combing through this many files: 15882
# {0: 17, 1: 9, 2: 29, 3: 2, 4: 43}
# [21.4778012  16.73525859 24.95245598 10.22676829 26.60771692]
# [0.17 0.09 0.29 0.02 0.43] 1.3180789218411042
# [0.21477801 0.16735258 0.24952456 0.10226768 0.26607717] 1.5613833221759084
# 92 Image ID: 1660 True Label: CC Correct? False Accuracy: 0.15217391304347827
# combing through this many files: 47361
# {0: 1, 1: 10, 2: 79, 3: 3, 4: 7}
# [13.82528369 18.44042074 38.18968356 18.72793868 10.81667313]
# [0.01 0.1  0.79 0.03 0.07] 0.7538757950998162
# [0.13825284 0.18440421 0.38189684 0.18727939 0.10816673] 1.507224385617767
# 93 Image ID: 45630 True Label: EC Correct? True Accuracy: 0.16129032258064516
# combing through this many files: 32047
# {0: 0, 1: 0, 2: 84, 3: 2, 4: 14}
# [12.30414591 14.84858412 41.60656078 18.46371312 12.77699623]
# [0.   0.   0.84 0.02 0.14] 0.4999531103628154
# [0.12304146 0.14848584 0.41606561 0.18463713 0.12776996] 1.4806644877414863
# 94 Image ID: 57162 True Label: LGSC Correct? False Accuracy: 0.1595744680851064
# combing through this many files: 31603
# {0: 2, 1: 0, 2: 64, 3: 2, 4: 32}
# [15.27324324 14.54065373 35.93622169 13.99216162 20.25771978]
# [0.02 0.   0.64 0.02 0.32] 0.8067236394597911
# [0.15273243 0.14540654 0.35936222 0.13992162 0.2025772 ] 1.5337724439077538
# 95 Image ID: 9254 True Label: MC Correct? False Accuracy: 0.15789473684210525
# combing through this many files: 5988
# {0: 2, 1: 9, 2: 75, 3: 5, 4: 9}
# [14.35868843 16.67332581 34.93728328 16.80217304 17.22852897]
# [0.02 0.09 0.75 0.05 0.09] 0.8772188384449586
# [0.14358688 0.16673326 0.34937283 0.16802173 0.17228529] 1.547436284802962
# 96 Image ID: 44432 True Label: HGSC Correct? False Accuracy: 0.15625
# combing through this many files: 15442
# {0: 12, 1: 2, 2: 22, 3: 1, 4: 63}
# [22.70642971 14.84326907 24.21399061  7.59938189 30.63692864]
# [0.12 0.02 0.22 0.01 0.63] 1.0029142277967422
# [0.2270643  0.14843269 0.24213991 0.07599382 0.30636929] 1.5214617297962276
# 97 Image ID: 1952 True Label: CC Correct? False Accuracy: 0.15463917525773196
# combing through this many files: 7612
# {0: 6, 1: 6, 2: 72, 3: 4, 4: 12}
# [16.72057432 17.06120697 34.36326729 14.57084161 17.2841101 ]
# [0.06 0.06 0.72 0.04 0.12] 0.9573188722205964
# [0.16720574 0.17061207 0.34363267 0.14570842 0.1728411 ] 1.5518770222852913
# 98 Image ID: 7204 True Label: EC Correct? True Accuracy: 0.16326530612244897
# combing through this many files: 7740
# {0: 18, 1: 25, 2: 20, 3: 1, 4: 36}
# [22.26626855 21.29791723 22.81190702 10.57801139 23.04589531]
# [0.18 0.25 0.2  0.01 0.36] 1.3909710411329836
# [0.22266269 0.21297917 0.22811907 0.10578011 0.23045895] 1.576844864004635
# 99 Image ID: 21260 True Label: LGSC Correct? False Accuracy: 0.16161616161616163
# combing through this many files: 39221
# {0: 1, 1: 0, 2: 70, 3: 0, 4: 29}
# [14.85827424 15.37125081 36.83771077 13.34169744 19.59106586]
# [0.01 0.   0.7  0.   0.29] 0.6547077309552507
# [0.14858274 0.15371251 0.36837711 0.13341698 0.19591066] 1.5271138209143877
# 100 Image ID: 44530 True Label: MC Correct? False Accuracy: 0.16
# combing through this many files: 20116
# {0: 7, 1: 17, 2: 49, 3: 6, 4: 21}
# [16.44766562 19.98352552 29.07489809 16.02780984 18.46610118]
# [0.07 0.17 0.49 0.06 0.21] 1.3334629811999847
# [0.16447666 0.19983525 0.29074898 0.1602781  0.18466101] 1.5832059365814497
# 101 Image ID: 3098 True Label: HGSC Correct? False Accuracy: 0.15841584158415842
# combing through this many files: 12071
# {0: 29, 1: 4, 2: 29, 3: 0, 4: 38}
# [24.72037762 16.31920201 24.78703212  7.8077076  26.36568059]
# [0.29 0.04 0.29 0.   0.38] 1.214404091916718
# [0.24720378 0.16319202 0.24787032 0.07807708 0.26365681] 1.5376424262266704
# 102 Image ID: 4827 True Label: CC Correct? False Accuracy: 0.1568627450980392
# combing through this many files: 6954
# {0: 7, 1: 7, 2: 58, 3: 5, 4: 23}
# [18.33262973 17.43775006 31.64745934 13.60356486 18.97859578]
# [0.07 0.07 0.58 0.05 0.23] 1.1760502541628552
# [0.1833263  0.1743775  0.31647459 0.13603565 0.18978596] 1.5664412498843825
# 103 Image ID: 18138 True Label: EC Correct? True Accuracy: 0.1650485436893204
# combing through this many files: 25493
# {0: 7, 1: 12, 2: 43, 3: 2, 4: 36}
# [19.81589211 18.1620142  29.29177653 10.13506895 22.59524753]
# [0.07 0.12 0.43 0.02 0.36] 1.249521866806985
# [0.19815892 0.18162014 0.29291777 0.10135069 0.22595248] 1.5583320205327973
# 104 Image ID: 33708 True Label: LGSC Correct? False Accuracy: 0.16346153846153846
# combing through this many files: 23824
# {0: 3, 1: 2, 2: 46, 3: 1, 4: 48}
# [18.09826512 15.29362395 31.35039416 11.49109793 23.76661944]
# [0.03 0.02 0.46 0.01 0.48] 0.938997346980004
# [0.18098265 0.15293624 0.31350394 0.11491098 0.23766619] 1.550304696408564
# 105 Image ID: 39252 True Label: MC Correct? False Accuracy: 0.1619047619047619
# combing through this many files: 8269
# {0: 10, 1: 12, 2: 9, 3: 3, 4: 66}
# [21.22102843 19.01623594 20.51560189  8.87928107 30.3678526 ]
# [0.1  0.12 0.09 0.03 0.66] 1.0808421688912486
# [0.21221028 0.19016236 0.20515602 0.08879281 0.30367853] 1.546500736439849
# 106 Image ID: 1295 True Label: HGSC Correct? False Accuracy: 0.16037735849056603
# combing through this many files: 9207
# {0: 14, 1: 6, 2: 11, 3: 1, 4: 68}
# [22.39959893 16.15282387 21.94982269  7.84736505 31.65038897]
# [0.14 0.06 0.11 0.01 0.68] 0.9951628728608803
# [0.22399599 0.16152824 0.21949823 0.07847365 0.31650389] 1.526281341741217
# 107 Image ID: 44581 True Label: CC Correct? False Accuracy: 0.1588785046728972
# combing through this many files: 14231
# {0: 8, 1: 25, 2: 19, 3: 2, 4: 46}
# [20.4587857  20.3628218  21.8039497  10.54031618 26.83412634]
# [0.08 0.25 0.19 0.02 0.46] 1.2996145147751714
# [0.20458786 0.20362822 0.2180395  0.10540316 0.26834126] 1.5709437739639371
# 108 Image ID: 286 True Label: EC Correct? False Accuracy: 0.1574074074074074
# combing through this many files: 7020
# {0: 5, 1: 14, 2: 53, 3: 5, 4: 23}
# [17.31467959 18.6373604  30.94310926 15.15515496 17.94969605]
# [0.05 0.14 0.53 0.05 0.23] 1.2493399851337594
# [0.1731468  0.1863736  0.30943109 0.15155155 0.17949696] 1.5739651159623482
# 109 Image ID: 3092 True Label: LGSC Correct? False Accuracy: 0.1559633027522936
# combing through this many files: 17198
# {0: 16, 1: 3, 2: 3, 3: 0, 4: 78}
# [24.55576946 15.37981029 16.1477048   6.29332221 37.62339371]
# [0.16 0.03 0.03 0.   0.78] 0.697406371255056
# [0.24555769 0.1537981  0.16147705 0.06293322 0.37623394] 1.4690200221949001
# 110 Image ID: 42260 True Label: MC Correct? True Accuracy: 0.16363636363636364
# combing through this many files: 5702
# {0: 3, 1: 1, 2: 88, 3: 1, 4: 7}
# [13.95249605 14.56211145 40.01757251 13.56155157 17.90626755]
# [0.03 0.01 0.88 0.01 0.07] 0.4959417114557827
# [0.13952496 0.14562112 0.40017573 0.13561552 0.17906268] 1.5008144486599995
# 111 Image ID: 25561 True Label: HGSC Correct? False Accuracy: 0.16216216216216217
# combing through this many files: 35126
# {0: 7, 1: 1, 2: 77, 3: 1, 4: 14}
# [16.83049268 15.33267317 36.48410377 13.39350392 17.95922648]
# [0.07 0.01 0.77 0.01 0.14] 0.7547582756130753
# [0.16830493 0.15332673 0.36484104 0.13393504 0.17959226] 1.5329332340924873
# 112 Image ID: 35197 True Label: CC Correct? False Accuracy: 0.16071428571428573
# combing through this many files: 9829
# {0: 3, 1: 1, 2: 84, 3: 2, 4: 10}
# [13.60702284 15.1450443  39.2050157  17.71500153 14.32791598]
# [0.03 0.01 0.84 0.02 0.1 ] 0.606204254536028
# [0.13607023 0.15145044 0.39205016 0.17715001 0.14327916] 1.5093575882556796
# 113 Image ID: 46444 True Label: EC Correct? True Accuracy: 0.168141592920354
# combing through this many files: 11033
# {0: 1, 1: 0, 2: 76, 3: 1, 4: 22}
# [13.34541782 14.58758191 39.50406247 17.09535956 15.46757786]
# [0.01 0.   0.76 0.01 0.22] 0.633783510817234
# [0.13345418 0.14587582 0.39504063 0.1709536  0.15467578] 1.5071445145505276
# 114 Image ID: 49872 True Label: LGSC Correct? False Accuracy: 0.16666666666666666
# combing through this many files: 23626
# {0: 3, 1: 2, 2: 24, 3: 1, 4: 70}
# [21.35143692 15.27802045 24.74241738  8.42862622 30.19949891]
# [0.03 0.02 0.24 0.01 0.7 ] 0.8216692859687106
# [0.21351437 0.1527802  0.24742417 0.08428626 0.30199499] 1.5323562048088155
# 115 Image ID: 56799 True Label: MC Correct? True Accuracy: 0.17391304347826086
# combing through this many files: 9142
# {0: 2, 1: 0, 2: 89, 3: 1, 4: 8}
# [10.23016525 13.64265933 44.93375476 18.91828625 12.27513335]
# [0.02 0.   0.89 0.01 0.08] 0.430065553284399
# [0.10230165 0.13642659 0.44933755 0.18918286 0.12275133] 1.4369290695390327
# 116 Image ID: 8213 True Label: HGSC Correct? False Accuracy: 0.1724137931034483
# combing through this many files: 14114
# {0: 20, 1: 11, 2: 22, 3: 2, 4: 45}
# [23.05140071 17.84625382 23.8978239   8.79958031 26.40494124]
# [0.2  0.11 0.22 0.02 0.45] 1.335364847859255
# [0.23051401 0.17846254 0.23897824 0.0879958  0.26404941] 1.5533778520240418
# 117 Image ID: 44976 True Label: CC Correct? False Accuracy: 0.17094017094017094
# combing through this many files: 42740
# {0: 11, 1: 23, 2: 46, 3: 3, 4: 17}
# [18.92233445 21.20821115 29.02946584 13.02093028 17.81905827]
# [0.11 0.23 0.46 0.03 0.17] 1.3444583570829527
# [0.18922334 0.21208211 0.29029466 0.1302093  0.17819058] 1.5757782387331902
# 118 Image ID: 14424 True Label: EC Correct? True Accuracy: 0.17796610169491525
# combing through this many files: 12257
# {0: 15, 1: 13, 2: 33, 3: 5, 4: 34}
# [20.85136191 18.57352462 24.04502859 11.75830187 24.77178285]
# [0.15 0.13 0.33 0.05 0.34] 1.4322372702735575
# [0.20851362 0.18573525 0.24045029 0.11758302 0.24771783] 1.579651108851873
# 119 Image ID: 54473 True Label: LGSC Correct? False Accuracy: 0.17647058823529413
# combing through this many files: 30669
# {0: 10, 1: 1, 2: 11, 3: 0, 4: 78}
# [23.7844018  15.63820225 18.54217949  6.38910529 35.64611079]
# [0.1  0.01 0.11 0.   0.78] 0.7129103148454636
# [0.23784402 0.15638202 0.1854218  0.06389105 0.35646111] 1.4876328443863531
# 120 Image ID: 56993 True Label: MC Correct? True Accuracy: 0.18333333333333332
# combing through this many files: 39650
# {0: 2, 1: 6, 2: 78, 3: 3, 4: 11}
# [14.62261175 17.79610622 36.18506995 17.91386486 13.48234762]
# [0.02 0.06 0.78 0.03 0.11] 0.7888419416118155
# [0.14622612 0.17796106 0.3618507  0.17913865 0.13482348] 1.534362709504702
# 121 Image ID: 46469 True Label: HGSC Correct? False Accuracy: 0.18181818181818182
# combing through this many files: 21643
# {0: 1, 1: 0, 2: 94, 3: 0, 4: 5}
# [10.45627367 13.60478678 45.37298034 16.43333582 14.1326234 ]
# [0.01 0.   0.94 0.   0.05] 0.25400120047702995
# [0.10456274 0.13604787 0.4537298  0.16433336 0.14132623] 1.4393356965534851
# 122 Image ID: 22425 True Label: CC Correct? False Accuracy: 0.18032786885245902
# combing through this many files: 5517
# {0: 11, 1: 14, 2: 50, 3: 1, 4: 24}
# [19.81054789 19.71054269 29.41736687 11.72224404 19.33929809]
# [0.11 0.14 0.5  0.01 0.24] 1.253189258299842
# [0.19810548 0.19710543 0.29417367 0.11722244 0.19339298] 1.5698112338889558
# 123 Image ID: 19030 True Label: EC Correct? True Accuracy: 0.18699186991869918
# combing through this many files: 13141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 107
#     105 index = next(label_indices[label])
#     106 row = sorted_val.loc[index]
# --> 107 predicted_label = process_sub_images(row.tile_path)
#     108 is_correct = predicted_label == row.label
#     109 total_correct += is_correct
#
# Cell In[37], line 68, in process_sub_images(path)
#      64 sub_image = Image.open(image_path)
#      66 sub_image = transform(sub_image).unsqueeze(0).to(device)
# ---> 68 outputs = model(sub_image)
#      69 probs = outputs.softmax(dim=1)
#      70 predicted_index = outputs.argmax(dim=1).item()
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[1], line 98, in VisionTransformer.forward(self, x)
#      95 x = x + self.pos_embed
#      96 x = self.pos_drop(x)
# ---> 98 x = self.blocks(x)
#      99 x = self.norm(x)
#     101 cls_token_final = x[:, 0]
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[1], line 74, in Block.forward(self, x)
#      72 def forward(self, x):
#      73     x = x + self.drop_path(self.attn(self.norm1(x)))
# ---> 74     x = x + self.mlp_drop(self.mlp(self.norm2(x)))
#      75     return x
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[1], line 55, in MLP.forward(self, x)
#      54 def forward(self, x):
# ---> 55     x = self.fc1(x)
#      56     x = self.act(x)
#      57     x = self.drop(x)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
